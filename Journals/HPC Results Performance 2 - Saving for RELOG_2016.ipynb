# %%
import pandas as pd
import numpy as np

# %%
EWfile = r'TEMP\EWG_center_2016.csv'
NSfile = r'TEMP\NSG_center_2016.csv'

# %%
EWdf = pd.read_csv(EWfile)
NSdf = pd.read_csv(NSfile)

# %%
EWdf['datetime'] = pd.to_datetime(EWdf['datetime'])
NSdf['datetime'] = pd.to_datetime(NSdf['datetime'])
EWdf.set_index('datetime', inplace=True)
NSdf.set_index('datetime', inplace=True)

# %%
EWdf.drop(columns=['DNI', 'DHI', 'GHI', 'temp_air', 'wind_speed', 
                   'Unnamed: 0', 'Orientation', 'Timestamp', 'solpos_zenith', 
                   'Row', 'Module',
                  'solpos_azimuth'], inplace=True)

NSdf.drop(columns=['DNI', 'DHI', 'GHI', 'temp_air', 'wind_speed', 
                   'Unnamed: 0', 'Orientation', 'Timestamp',
                   'Row', 'Module',
                  ], inplace=True)

# %%
weatherfile = r'C:\Users\sayala\Documents\GitHub\Studies\SouthPole\Journals\TEMP\SouthPole_2021_WeatherFile.csv'
weatherfile = r'C:\Users\sayala\Documents\GitHub\Studies\SouthPole\Journals\IOFiles\POWER_Point_Hourly_20160101_20161231_090d00S_000d00E_LT.csv'

# %%
df = pd.read_csv(weatherfile, skiprows=2)

# %%
#df['datetime'] = pd.to_datetime(df[['Year','Month','Day', 'Hour']], format="%Y-%m-%d_%H%M").dt.tz_localize(tz='Etc/GMT+3')
df['datetime'] = pd.to_datetime(df[['Year','Month','Day', 'Hour']], format="%Y-%m-%d_%H%M").dt.tz_localize(tz='Etc/GMT-14')

df.set_index('datetime', inplace=True)

# %%
NSdf.head(25)
# Out:
#                            solpos_zenith  solpos_azimuth  SouthFacing_POA  \
# datetime
# 2016-01-01 01:00:00+14:00      66.904413        8.206346       1148.19552
# 2016-01-01 02:00:00+14:00      66.907436      353.211321       1006.75920
# 2016-01-01 03:00:00+14:00      66.910472      338.216295        817.70562
# 2016-01-01 04:00:00+14:00      66.913522      323.221267        592.97314
# 2016-01-01 05:00:00+14:00      66.916584      308.226237        352.78876
# 2016-01-01 06:00:00+14:00      66.919661      293.231205        396.35798
# 2016-01-01 07:00:00+14:00      66.922750      278.236172        527.05804
# 2016-01-01 08:00:00+14:00      66.925853      263.241136        472.72016
# 2016-01-01 09:00:00+14:00      66.928969      248.246098        713.88714
# 2016-01-01 10:00:00+14:00      66.932099      233.251059        810.66950
# 2016-01-01 11:00:00+14:00      66.935242      218.256018        839.25690
# 2016-01-01 12:00:00+14:00      66.938398      203.260974        828.02740
# 2016-01-01 13:00:00+14:00      66.941568      188.265929        781.53120
# 2016-01-01 14:00:00+14:00      66.944751      173.270881        701.81838
# 2016-01-01 15:00:00+14:00      66.947947      158.275832        588.24812
# 2016-01-01 11:00:00+14:00         354.184631
# 2016-01-01 12:00:00+14:00         349.810870
# 2016-01-01 13:00:00+14:00         331.732144
# 2016-01-01 14:00:00+14:00         300.263209
# 2016-01-01 15:00:00+14:00         254.400574
# 2016-01-01 16:00:00+14:00         199.619854
# 2016-01-01 17:00:00+14:00         146.010636
# 2016-01-01 18:00:00+14:00         216.544886
# 2016-01-01 19:00:00+14:00         239.094605
# 2016-01-01 20:00:00+14:00         356.406175
# 2016-01-01 21:00:00+14:00         449.825812
# 2016-01-01 22:00:00+14:00         400.249144
# 2016-01-01 23:00:00+14:00         269.808096
# 2016-01-02 01:00:00+14:00         233.999058
# 2016-01-02 02:00:00+14:00         220.411761

# %%
NSdf.tail(1)
# Out:
#                            solpos_zenith  solpos_azimuth  SouthFacing_POA  \
# datetime
# 2016-12-31 23:00:00+14:00      66.955043       38.288568        813.91228
#
#                            NorthFacing_POA  North_Performance  \
# datetime
# 2016-12-31 23:00:00+14:00         581.8314         247.291962
#
#                            South_Performance
# datetime
# 2016-12-31 23:00:00+14:00         338.492324

# %%
df.head(1)
# Out:
#                            Year  Month  Day  Hour      GHI       DNI     DHI  \
# datetime
# 2016-01-01 00:00:00+14:00  2016      1    1     0  478.156  1077.961  65.156
#
#                              Tdry    twet    Tdew   Wspd    Wdir      rh  \
# datetime
# 2016-01-01 00:00:00+14:00 -30.611 -30.931 -31.244  3.108  53.793  93.375
#
#                               pres  snow   Alb  aod
# datetime
# 2016-01-01 00:00:00+14:00  684.896   NaN  0.75  0.0

# %%
df.tail(1)
# Out:
#                            Year  Month  Day  Hour      GHI     DNI      DHI  \
# datetime
# 2016-12-31 23:00:00+14:00  2016     12   31    23  377.672  274.93  272.211
#
#                              Tdry    twet    Tdew   Wspd   Wdir      rh  \
# datetime
# 2016-12-31 23:00:00+14:00 -22.791 -23.142 -23.494  4.336  6.933  93.188
#
#                              pres  snow    Alb  aod
# datetime
# 2016-12-31 23:00:00+14:00  692.29   NaN  0.797  0.0

# %%
#EWdf.rename(columns={"temp_air": "Tdry", "wind_speed": "Wspd"}, inplace=True)
#NSdf.rename(columns={"temp_air": "Tdry", "wind_speed": "Wspd"}, inplace=True)

# %%
result = pd.concat([df, EWdf], axis=1)
result = pd.concat([result, NSdf], axis=1)

# %%
result = result.tz_convert(tz='Etc/GMT-14')

# %%
#result['Row'] = 4
#result['Module'] = 10
#result.drop(columns=['Unnamed: 0'], inplace=True)
#result.drop(columns=['Orientation'], inplace=True)
#result.drop(columns=['Timestamp'], inplace=True)

# %%
result.to_csv(r'TEMP\HPC_SAMFormat_2016.csv')

# %%
result.bfill().to_csv(r'TEMP\HPC_SAMFormat_2016_bfill.csv')
