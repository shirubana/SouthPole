# %% [markdown]
# # Runs 11/14, various hours

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
# Exploring Results Folder 
savefolder=r'C:\Users\sayala\Documents\GitHub\Studies\SouthPole\Journals\TEMP\SP2\results'

filelist = sorted(os.listdir(savefolder))
print('{} files in the directory'.format(filelist.__len__()))

x_all = []
y_all = []
z_all = []
rearZ_all = []
mattype_all = []
rearMat_all = []
Wm2Front_all = []
Wm2Back_all = []
pos_all = []
errors_all = []
orientation_all = []
mm_all = []
rr_all = []
CH_all = []
rtr_all = []

timestamplist = [x[10:25] for x in filelist]
orientation = [x[26:28] for x in filelist]
mm = [x[29:31] for x in filelist]
rr = [x[32:34] for x in filelist]
CH = [x[38:41] for x in filelist]
rtr = [x[46:47] for x in filelist]

print("timestamplist", np.unique(timestamplist).tolist())
print("orientation", np.unique(orientation).tolist())
print("Num Rows (indexed on 0)", np.unique(rr).tolist())
print("Num Modules per Row (indexed on 0)", np.unique(mm).tolist())
print("Clearance Heights", np.unique(CH).tolist())
print("Pitches", np.unique(rtr).tolist())
# Out:
# 450 files in the directory
# timestamplist ['2021-12-21_0200', '2021-12-21_0500', '2021-12-21_0800', '2021-12-21_1100', '2021-12-21_1400', '2021-12-21_1700', '2021-12-21_1800', '2021-12-21_2000', '2021-12-21_2300']
# orientation ['EW', 'NS']
# Num Rows (indexed on 0) ['00', '01', '02', '03', '04']
# Num Modules per Row (indexed on 0) ['00', '01', '02', '03', '04']
# Clearance Heights ['0.6']
# Pitches ['8']

# %% [markdown]
# ## Loading All files into Dataframe

# %%
for ii in range(0, len(timestamplist)):

    print("Working on entry "+str(ii)+" filename "+filelist[ii])
    #filename = 'irr_1axis_'+timestamplist[ii]+'_'+orientation[ii]+'_'+mm[ii]+'-'+rr[ii]+'_CH_'+CH[ii]+'_rtr_'+rtr[ii]+'.csv_Row'+str(int(rr[0]))+'_Module'+str(int(mm[0]))+'.csv'

    posSampled = 9*6

    try:
        data = pd.read_csv(os.path.join(savefolder,filelist[ii]))

        # Save all the values
        x_all.append(list(data['x']))
        y_all.append(list(data['y']))
        z_all.append(list(data['z']))
        rearZ_all.append(list(data['rearZ']))
        mattype_all.append(list(data['mattype']))
        rearMat_all.append(list(data['rearMat']))
        Wm2Front_all.append(list(data['Wm2Front']))
        Wm2Back_all.append(list(data['Wm2Back']))

        # Saving position and timestamp for indexing
        pos_all.append(ii)
#            timestamp_all.append(timestamplist[i])

    except:
        print('*** Missing positions ', ii)
        errors_all.append(ii)


df = pd.DataFrame(list(zip(timestamplist,orientation,mm, rr, CH, rtr, x_all,y_all,z_all,rearZ_all,
                           mattype_all,rearMat_all,Wm2Front_all,Wm2Back_all)),
                          columns=['Timestamp', 'Orientation', 'Module', 'Row', 'CH', 'rtr', 'x','y','z','rearZ',
                                   'mattype','rearMat','Wm2Front','Wm2Back'])


df.to_csv('Compiled.csv')

#errorfile = os.path.join(savefolder, 'ERRORS'+withopt+'.txt')
#with open(errorfile, 'w') as f:
#    for s in errors_all:
#        f.write(str(s) + '\n')
print("FINISHED")
# Out:
# Working on entry 0 filename irr_1axis_2021-12-21_0200_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 1 filename irr_1axis_2021-12-21_0200_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 2 filename irr_1axis_2021-12-21_0200_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 3 filename irr_1axis_2021-12-21_0200_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 4 filename irr_1axis_2021-12-21_0200_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 5 filename irr_1axis_2021-12-21_0200_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 6 filename irr_1axis_2021-12-21_0200_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 7 filename irr_1axis_2021-12-21_0200_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 8 filename irr_1axis_2021-12-21_0200_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 9 filename irr_1axis_2021-12-21_0200_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 10 filename irr_1axis_2021-12-21_0200_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 11 filename irr_1axis_2021-12-21_0200_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 12 filename irr_1axis_2021-12-21_0200_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 13 filename irr_1axis_2021-12-21_0200_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 14 filename irr_1axis_2021-12-21_0200_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 15 filename irr_1axis_2021-12-21_0200_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 16 filename irr_1axis_2021-12-21_0200_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 17 filename irr_1axis_2021-12-21_0200_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 18 filename irr_1axis_2021-12-21_0200_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 19 filename irr_1axis_2021-12-21_0200_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 20 filename irr_1axis_2021-12-21_0200_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 21 filename irr_1axis_2021-12-21_0200_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 22 filename irr_1axis_2021-12-21_0200_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 23 filename irr_1axis_2021-12-21_0200_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 24 filename irr_1axis_2021-12-21_0200_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 25 filename irr_1axis_2021-12-21_0200_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 26 filename irr_1axis_2021-12-21_0200_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 27 filename irr_1axis_2021-12-21_0200_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 28 filename irr_1axis_2021-12-21_0200_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 29 filename irr_1axis_2021-12-21_0200_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 30 filename irr_1axis_2021-12-21_0200_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 31 filename irr_1axis_2021-12-21_0200_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 32 filename irr_1axis_2021-12-21_0200_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 33 filename irr_1axis_2021-12-21_0200_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 34 filename irr_1axis_2021-12-21_0200_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 35 filename irr_1axis_2021-12-21_0200_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 36 filename irr_1axis_2021-12-21_0200_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 37 filename irr_1axis_2021-12-21_0200_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 38 filename irr_1axis_2021-12-21_0200_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 39 filename irr_1axis_2021-12-21_0200_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 40 filename irr_1axis_2021-12-21_0200_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 41 filename irr_1axis_2021-12-21_0200_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 42 filename irr_1axis_2021-12-21_0200_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 43 filename irr_1axis_2021-12-21_0200_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 44 filename irr_1axis_2021-12-21_0200_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 45 filename irr_1axis_2021-12-21_0200_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 46 filename irr_1axis_2021-12-21_0200_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 47 filename irr_1axis_2021-12-21_0200_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 48 filename irr_1axis_2021-12-21_0200_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 49 filename irr_1axis_2021-12-21_0200_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 50 filename irr_1axis_2021-12-21_0500_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 51 filename irr_1axis_2021-12-21_0500_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 52 filename irr_1axis_2021-12-21_0500_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 53 filename irr_1axis_2021-12-21_0500_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 54 filename irr_1axis_2021-12-21_0500_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 55 filename irr_1axis_2021-12-21_0500_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 56 filename irr_1axis_2021-12-21_0500_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 57 filename irr_1axis_2021-12-21_0500_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 58 filename irr_1axis_2021-12-21_0500_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 59 filename irr_1axis_2021-12-21_0500_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 60 filename irr_1axis_2021-12-21_0500_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 61 filename irr_1axis_2021-12-21_0500_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 62 filename irr_1axis_2021-12-21_0500_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 63 filename irr_1axis_2021-12-21_0500_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 64 filename irr_1axis_2021-12-21_0500_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 65 filename irr_1axis_2021-12-21_0500_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 66 filename irr_1axis_2021-12-21_0500_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 67 filename irr_1axis_2021-12-21_0500_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 68 filename irr_1axis_2021-12-21_0500_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 69 filename irr_1axis_2021-12-21_0500_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 70 filename irr_1axis_2021-12-21_0500_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 71 filename irr_1axis_2021-12-21_0500_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 72 filename irr_1axis_2021-12-21_0500_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 73 filename irr_1axis_2021-12-21_0500_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 74 filename irr_1axis_2021-12-21_0500_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 75 filename irr_1axis_2021-12-21_0500_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 76 filename irr_1axis_2021-12-21_0500_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 77 filename irr_1axis_2021-12-21_0500_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 78 filename irr_1axis_2021-12-21_0500_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 79 filename irr_1axis_2021-12-21_0500_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 80 filename irr_1axis_2021-12-21_0500_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 81 filename irr_1axis_2021-12-21_0500_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 82 filename irr_1axis_2021-12-21_0500_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 83 filename irr_1axis_2021-12-21_0500_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 84 filename irr_1axis_2021-12-21_0500_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 85 filename irr_1axis_2021-12-21_0500_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 86 filename irr_1axis_2021-12-21_0500_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 87 filename irr_1axis_2021-12-21_0500_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 88 filename irr_1axis_2021-12-21_0500_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 89 filename irr_1axis_2021-12-21_0500_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 90 filename irr_1axis_2021-12-21_0500_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 91 filename irr_1axis_2021-12-21_0500_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 92 filename irr_1axis_2021-12-21_0500_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 93 filename irr_1axis_2021-12-21_0500_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 94 filename irr_1axis_2021-12-21_0500_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 95 filename irr_1axis_2021-12-21_0500_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 96 filename irr_1axis_2021-12-21_0500_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 97 filename irr_1axis_2021-12-21_0500_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 98 filename irr_1axis_2021-12-21_0500_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 99 filename irr_1axis_2021-12-21_0500_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 100 filename irr_1axis_2021-12-21_0800_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 101 filename irr_1axis_2021-12-21_0800_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 102 filename irr_1axis_2021-12-21_0800_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 103 filename irr_1axis_2021-12-21_0800_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 104 filename irr_1axis_2021-12-21_0800_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 105 filename irr_1axis_2021-12-21_0800_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 106 filename irr_1axis_2021-12-21_0800_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 107 filename irr_1axis_2021-12-21_0800_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 108 filename irr_1axis_2021-12-21_0800_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 109 filename irr_1axis_2021-12-21_0800_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 110 filename irr_1axis_2021-12-21_0800_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 111 filename irr_1axis_2021-12-21_0800_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 112 filename irr_1axis_2021-12-21_0800_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 113 filename irr_1axis_2021-12-21_0800_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 114 filename irr_1axis_2021-12-21_0800_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 115 filename irr_1axis_2021-12-21_0800_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 116 filename irr_1axis_2021-12-21_0800_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 117 filename irr_1axis_2021-12-21_0800_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 118 filename irr_1axis_2021-12-21_0800_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 119 filename irr_1axis_2021-12-21_0800_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 120 filename irr_1axis_2021-12-21_0800_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 121 filename irr_1axis_2021-12-21_0800_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 122 filename irr_1axis_2021-12-21_0800_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 123 filename irr_1axis_2021-12-21_0800_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 124 filename irr_1axis_2021-12-21_0800_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 125 filename irr_1axis_2021-12-21_0800_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 126 filename irr_1axis_2021-12-21_0800_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 127 filename irr_1axis_2021-12-21_0800_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 128 filename irr_1axis_2021-12-21_0800_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 129 filename irr_1axis_2021-12-21_0800_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 130 filename irr_1axis_2021-12-21_0800_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 131 filename irr_1axis_2021-12-21_0800_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 132 filename irr_1axis_2021-12-21_0800_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 133 filename irr_1axis_2021-12-21_0800_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 134 filename irr_1axis_2021-12-21_0800_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 135 filename irr_1axis_2021-12-21_0800_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 136 filename irr_1axis_2021-12-21_0800_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 137 filename irr_1axis_2021-12-21_0800_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 138 filename irr_1axis_2021-12-21_0800_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 139 filename irr_1axis_2021-12-21_0800_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 140 filename irr_1axis_2021-12-21_0800_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 141 filename irr_1axis_2021-12-21_0800_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 142 filename irr_1axis_2021-12-21_0800_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 143 filename irr_1axis_2021-12-21_0800_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 144 filename irr_1axis_2021-12-21_0800_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 145 filename irr_1axis_2021-12-21_0800_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 146 filename irr_1axis_2021-12-21_0800_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 147 filename irr_1axis_2021-12-21_0800_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 148 filename irr_1axis_2021-12-21_0800_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 149 filename irr_1axis_2021-12-21_0800_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 150 filename irr_1axis_2021-12-21_1100_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 151 filename irr_1axis_2021-12-21_1100_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 152 filename irr_1axis_2021-12-21_1100_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 153 filename irr_1axis_2021-12-21_1100_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 154 filename irr_1axis_2021-12-21_1100_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 155 filename irr_1axis_2021-12-21_1100_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 156 filename irr_1axis_2021-12-21_1100_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 157 filename irr_1axis_2021-12-21_1100_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 158 filename irr_1axis_2021-12-21_1100_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 159 filename irr_1axis_2021-12-21_1100_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 160 filename irr_1axis_2021-12-21_1100_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 161 filename irr_1axis_2021-12-21_1100_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 162 filename irr_1axis_2021-12-21_1100_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 163 filename irr_1axis_2021-12-21_1100_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 164 filename irr_1axis_2021-12-21_1100_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 165 filename irr_1axis_2021-12-21_1100_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 166 filename irr_1axis_2021-12-21_1100_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 167 filename irr_1axis_2021-12-21_1100_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 168 filename irr_1axis_2021-12-21_1100_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 169 filename irr_1axis_2021-12-21_1100_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 170 filename irr_1axis_2021-12-21_1100_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 171 filename irr_1axis_2021-12-21_1100_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 172 filename irr_1axis_2021-12-21_1100_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 173 filename irr_1axis_2021-12-21_1100_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 174 filename irr_1axis_2021-12-21_1100_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 175 filename irr_1axis_2021-12-21_1100_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 176 filename irr_1axis_2021-12-21_1100_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 177 filename irr_1axis_2021-12-21_1100_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 178 filename irr_1axis_2021-12-21_1100_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 179 filename irr_1axis_2021-12-21_1100_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 180 filename irr_1axis_2021-12-21_1100_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 181 filename irr_1axis_2021-12-21_1100_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 182 filename irr_1axis_2021-12-21_1100_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 183 filename irr_1axis_2021-12-21_1100_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 184 filename irr_1axis_2021-12-21_1100_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 185 filename irr_1axis_2021-12-21_1100_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 186 filename irr_1axis_2021-12-21_1100_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 187 filename irr_1axis_2021-12-21_1100_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 188 filename irr_1axis_2021-12-21_1100_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 189 filename irr_1axis_2021-12-21_1100_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 190 filename irr_1axis_2021-12-21_1100_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 191 filename irr_1axis_2021-12-21_1100_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 192 filename irr_1axis_2021-12-21_1100_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 193 filename irr_1axis_2021-12-21_1100_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 194 filename irr_1axis_2021-12-21_1100_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 195 filename irr_1axis_2021-12-21_1100_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 196 filename irr_1axis_2021-12-21_1100_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 197 filename irr_1axis_2021-12-21_1100_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 198 filename irr_1axis_2021-12-21_1100_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 199 filename irr_1axis_2021-12-21_1100_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 200 filename irr_1axis_2021-12-21_1400_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 201 filename irr_1axis_2021-12-21_1400_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 202 filename irr_1axis_2021-12-21_1400_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 203 filename irr_1axis_2021-12-21_1400_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 204 filename irr_1axis_2021-12-21_1400_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 205 filename irr_1axis_2021-12-21_1400_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 206 filename irr_1axis_2021-12-21_1400_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 207 filename irr_1axis_2021-12-21_1400_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 208 filename irr_1axis_2021-12-21_1400_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 209 filename irr_1axis_2021-12-21_1400_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 210 filename irr_1axis_2021-12-21_1400_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 211 filename irr_1axis_2021-12-21_1400_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 212 filename irr_1axis_2021-12-21_1400_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 213 filename irr_1axis_2021-12-21_1400_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 214 filename irr_1axis_2021-12-21_1400_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 215 filename irr_1axis_2021-12-21_1400_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 216 filename irr_1axis_2021-12-21_1400_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 217 filename irr_1axis_2021-12-21_1400_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 218 filename irr_1axis_2021-12-21_1400_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 219 filename irr_1axis_2021-12-21_1400_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 220 filename irr_1axis_2021-12-21_1400_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 221 filename irr_1axis_2021-12-21_1400_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 222 filename irr_1axis_2021-12-21_1400_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 223 filename irr_1axis_2021-12-21_1400_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 224 filename irr_1axis_2021-12-21_1400_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 225 filename irr_1axis_2021-12-21_1400_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 226 filename irr_1axis_2021-12-21_1400_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 227 filename irr_1axis_2021-12-21_1400_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 228 filename irr_1axis_2021-12-21_1400_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 229 filename irr_1axis_2021-12-21_1400_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 230 filename irr_1axis_2021-12-21_1400_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 231 filename irr_1axis_2021-12-21_1400_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 232 filename irr_1axis_2021-12-21_1400_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 233 filename irr_1axis_2021-12-21_1400_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 234 filename irr_1axis_2021-12-21_1400_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 235 filename irr_1axis_2021-12-21_1400_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 236 filename irr_1axis_2021-12-21_1400_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 237 filename irr_1axis_2021-12-21_1400_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 238 filename irr_1axis_2021-12-21_1400_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 239 filename irr_1axis_2021-12-21_1400_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 240 filename irr_1axis_2021-12-21_1400_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 241 filename irr_1axis_2021-12-21_1400_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 242 filename irr_1axis_2021-12-21_1400_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 243 filename irr_1axis_2021-12-21_1400_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 244 filename irr_1axis_2021-12-21_1400_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 245 filename irr_1axis_2021-12-21_1400_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 246 filename irr_1axis_2021-12-21_1400_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 247 filename irr_1axis_2021-12-21_1400_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 248 filename irr_1axis_2021-12-21_1400_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 249 filename irr_1axis_2021-12-21_1400_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 250 filename irr_1axis_2021-12-21_1700_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 251 filename irr_1axis_2021-12-21_1700_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 252 filename irr_1axis_2021-12-21_1700_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 253 filename irr_1axis_2021-12-21_1700_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 254 filename irr_1axis_2021-12-21_1700_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 255 filename irr_1axis_2021-12-21_1700_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 256 filename irr_1axis_2021-12-21_1700_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 257 filename irr_1axis_2021-12-21_1700_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 258 filename irr_1axis_2021-12-21_1700_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 259 filename irr_1axis_2021-12-21_1700_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 260 filename irr_1axis_2021-12-21_1700_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 261 filename irr_1axis_2021-12-21_1700_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 262 filename irr_1axis_2021-12-21_1700_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 263 filename irr_1axis_2021-12-21_1700_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 264 filename irr_1axis_2021-12-21_1700_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 265 filename irr_1axis_2021-12-21_1700_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 266 filename irr_1axis_2021-12-21_1700_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 267 filename irr_1axis_2021-12-21_1700_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 268 filename irr_1axis_2021-12-21_1700_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 269 filename irr_1axis_2021-12-21_1700_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 270 filename irr_1axis_2021-12-21_1700_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 271 filename irr_1axis_2021-12-21_1700_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 272 filename irr_1axis_2021-12-21_1700_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 273 filename irr_1axis_2021-12-21_1700_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 274 filename irr_1axis_2021-12-21_1700_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 275 filename irr_1axis_2021-12-21_1700_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 276 filename irr_1axis_2021-12-21_1700_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 277 filename irr_1axis_2021-12-21_1700_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 278 filename irr_1axis_2021-12-21_1700_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 279 filename irr_1axis_2021-12-21_1700_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 280 filename irr_1axis_2021-12-21_1700_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 281 filename irr_1axis_2021-12-21_1700_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 282 filename irr_1axis_2021-12-21_1700_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 283 filename irr_1axis_2021-12-21_1700_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 284 filename irr_1axis_2021-12-21_1700_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 285 filename irr_1axis_2021-12-21_1700_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 286 filename irr_1axis_2021-12-21_1700_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 287 filename irr_1axis_2021-12-21_1700_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 288 filename irr_1axis_2021-12-21_1700_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 289 filename irr_1axis_2021-12-21_1700_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 290 filename irr_1axis_2021-12-21_1700_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 291 filename irr_1axis_2021-12-21_1700_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 292 filename irr_1axis_2021-12-21_1700_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 293 filename irr_1axis_2021-12-21_1700_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 294 filename irr_1axis_2021-12-21_1700_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 295 filename irr_1axis_2021-12-21_1700_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 296 filename irr_1axis_2021-12-21_1700_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 297 filename irr_1axis_2021-12-21_1700_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 298 filename irr_1axis_2021-12-21_1700_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 299 filename irr_1axis_2021-12-21_1700_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 300 filename irr_1axis_2021-12-21_1800_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 301 filename irr_1axis_2021-12-21_1800_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 302 filename irr_1axis_2021-12-21_1800_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 303 filename irr_1axis_2021-12-21_1800_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 304 filename irr_1axis_2021-12-21_1800_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 305 filename irr_1axis_2021-12-21_1800_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 306 filename irr_1axis_2021-12-21_1800_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 307 filename irr_1axis_2021-12-21_1800_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 308 filename irr_1axis_2021-12-21_1800_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 309 filename irr_1axis_2021-12-21_1800_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 310 filename irr_1axis_2021-12-21_1800_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 311 filename irr_1axis_2021-12-21_1800_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 312 filename irr_1axis_2021-12-21_1800_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 313 filename irr_1axis_2021-12-21_1800_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 314 filename irr_1axis_2021-12-21_1800_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 315 filename irr_1axis_2021-12-21_1800_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 316 filename irr_1axis_2021-12-21_1800_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 317 filename irr_1axis_2021-12-21_1800_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 318 filename irr_1axis_2021-12-21_1800_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 319 filename irr_1axis_2021-12-21_1800_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 320 filename irr_1axis_2021-12-21_1800_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 321 filename irr_1axis_2021-12-21_1800_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 322 filename irr_1axis_2021-12-21_1800_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 323 filename irr_1axis_2021-12-21_1800_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 324 filename irr_1axis_2021-12-21_1800_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 325 filename irr_1axis_2021-12-21_1800_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 326 filename irr_1axis_2021-12-21_1800_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 327 filename irr_1axis_2021-12-21_1800_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 328 filename irr_1axis_2021-12-21_1800_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 329 filename irr_1axis_2021-12-21_1800_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 330 filename irr_1axis_2021-12-21_1800_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 331 filename irr_1axis_2021-12-21_1800_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 332 filename irr_1axis_2021-12-21_1800_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 333 filename irr_1axis_2021-12-21_1800_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 334 filename irr_1axis_2021-12-21_1800_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 335 filename irr_1axis_2021-12-21_1800_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 336 filename irr_1axis_2021-12-21_1800_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 337 filename irr_1axis_2021-12-21_1800_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 338 filename irr_1axis_2021-12-21_1800_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 339 filename irr_1axis_2021-12-21_1800_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 340 filename irr_1axis_2021-12-21_1800_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 341 filename irr_1axis_2021-12-21_1800_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 342 filename irr_1axis_2021-12-21_1800_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 343 filename irr_1axis_2021-12-21_1800_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 344 filename irr_1axis_2021-12-21_1800_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 345 filename irr_1axis_2021-12-21_1800_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 346 filename irr_1axis_2021-12-21_1800_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 347 filename irr_1axis_2021-12-21_1800_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 348 filename irr_1axis_2021-12-21_1800_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 349 filename irr_1axis_2021-12-21_1800_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 350 filename irr_1axis_2021-12-21_2000_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 351 filename irr_1axis_2021-12-21_2000_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 352 filename irr_1axis_2021-12-21_2000_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 353 filename irr_1axis_2021-12-21_2000_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 354 filename irr_1axis_2021-12-21_2000_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 355 filename irr_1axis_2021-12-21_2000_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 356 filename irr_1axis_2021-12-21_2000_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 357 filename irr_1axis_2021-12-21_2000_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 358 filename irr_1axis_2021-12-21_2000_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 359 filename irr_1axis_2021-12-21_2000_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 360 filename irr_1axis_2021-12-21_2000_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 361 filename irr_1axis_2021-12-21_2000_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 362 filename irr_1axis_2021-12-21_2000_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 363 filename irr_1axis_2021-12-21_2000_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 364 filename irr_1axis_2021-12-21_2000_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 365 filename irr_1axis_2021-12-21_2000_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 366 filename irr_1axis_2021-12-21_2000_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 367 filename irr_1axis_2021-12-21_2000_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 368 filename irr_1axis_2021-12-21_2000_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 369 filename irr_1axis_2021-12-21_2000_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 370 filename irr_1axis_2021-12-21_2000_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 371 filename irr_1axis_2021-12-21_2000_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 372 filename irr_1axis_2021-12-21_2000_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 373 filename irr_1axis_2021-12-21_2000_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 374 filename irr_1axis_2021-12-21_2000_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 375 filename irr_1axis_2021-12-21_2000_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 376 filename irr_1axis_2021-12-21_2000_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 377 filename irr_1axis_2021-12-21_2000_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 378 filename irr_1axis_2021-12-21_2000_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 379 filename irr_1axis_2021-12-21_2000_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 380 filename irr_1axis_2021-12-21_2000_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 381 filename irr_1axis_2021-12-21_2000_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 382 filename irr_1axis_2021-12-21_2000_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 383 filename irr_1axis_2021-12-21_2000_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 384 filename irr_1axis_2021-12-21_2000_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 385 filename irr_1axis_2021-12-21_2000_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 386 filename irr_1axis_2021-12-21_2000_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 387 filename irr_1axis_2021-12-21_2000_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 388 filename irr_1axis_2021-12-21_2000_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 389 filename irr_1axis_2021-12-21_2000_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 390 filename irr_1axis_2021-12-21_2000_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 391 filename irr_1axis_2021-12-21_2000_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 392 filename irr_1axis_2021-12-21_2000_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 393 filename irr_1axis_2021-12-21_2000_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 394 filename irr_1axis_2021-12-21_2000_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 395 filename irr_1axis_2021-12-21_2000_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 396 filename irr_1axis_2021-12-21_2000_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 397 filename irr_1axis_2021-12-21_2000_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 398 filename irr_1axis_2021-12-21_2000_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 399 filename irr_1axis_2021-12-21_2000_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 400 filename irr_1axis_2021-12-21_2300_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 401 filename irr_1axis_2021-12-21_2300_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 402 filename irr_1axis_2021-12-21_2300_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 403 filename irr_1axis_2021-12-21_2300_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 404 filename irr_1axis_2021-12-21_2300_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 405 filename irr_1axis_2021-12-21_2300_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 406 filename irr_1axis_2021-12-21_2300_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 407 filename irr_1axis_2021-12-21_2300_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 408 filename irr_1axis_2021-12-21_2300_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 409 filename irr_1axis_2021-12-21_2300_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 410 filename irr_1axis_2021-12-21_2300_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 411 filename irr_1axis_2021-12-21_2300_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 412 filename irr_1axis_2021-12-21_2300_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 413 filename irr_1axis_2021-12-21_2300_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 414 filename irr_1axis_2021-12-21_2300_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 415 filename irr_1axis_2021-12-21_2300_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 416 filename irr_1axis_2021-12-21_2300_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 417 filename irr_1axis_2021-12-21_2300_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 418 filename irr_1axis_2021-12-21_2300_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 419 filename irr_1axis_2021-12-21_2300_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 420 filename irr_1axis_2021-12-21_2300_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 421 filename irr_1axis_2021-12-21_2300_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 422 filename irr_1axis_2021-12-21_2300_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 423 filename irr_1axis_2021-12-21_2300_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 424 filename irr_1axis_2021-12-21_2300_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Working on entry 425 filename irr_1axis_2021-12-21_2300_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Working on entry 426 filename irr_1axis_2021-12-21_2300_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Working on entry 427 filename irr_1axis_2021-12-21_2300_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Working on entry 428 filename irr_1axis_2021-12-21_2300_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Working on entry 429 filename irr_1axis_2021-12-21_2300_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Working on entry 430 filename irr_1axis_2021-12-21_2300_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Working on entry 431 filename irr_1axis_2021-12-21_2300_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Working on entry 432 filename irr_1axis_2021-12-21_2300_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Working on entry 433 filename irr_1axis_2021-12-21_2300_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Working on entry 434 filename irr_1axis_2021-12-21_2300_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Working on entry 435 filename irr_1axis_2021-12-21_2300_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Working on entry 436 filename irr_1axis_2021-12-21_2300_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Working on entry 437 filename irr_1axis_2021-12-21_2300_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Working on entry 438 filename irr_1axis_2021-12-21_2300_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Working on entry 439 filename irr_1axis_2021-12-21_2300_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Working on entry 440 filename irr_1axis_2021-12-21_2300_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Working on entry 441 filename irr_1axis_2021-12-21_2300_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Working on entry 442 filename irr_1axis_2021-12-21_2300_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Working on entry 443 filename irr_1axis_2021-12-21_2300_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Working on entry 444 filename irr_1axis_2021-12-21_2300_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Working on entry 445 filename irr_1axis_2021-12-21_2300_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Working on entry 446 filename irr_1axis_2021-12-21_2300_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Working on entry 447 filename irr_1axis_2021-12-21_2300_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Working on entry 448 filename irr_1axis_2021-12-21_2300_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Working on entry 449 filename irr_1axis_2021-12-21_2300_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# FINISHED

# %% [markdown]
# ## Join Weather Data (DNI, DHI, WSPD, ETC)

# %%
df['datetimes'] = pd.to_datetime(df['Timestamp'], format="%Y-%m-%d_%H%M").dt.tz_localize(tz='Etc/GMT+3')
uniquetimes = df['datetimes'].unique()
print(uniquetimes)
# Out:
# <DatetimeArray>
# ['2021-12-21 02:00:00-03:00', '2021-12-21 05:00:00-03:00',
#  '2021-12-21 08:00:00-03:00', '2021-12-21 11:00:00-03:00',
#  '2021-12-21 14:00:00-03:00', '2021-12-21 17:00:00-03:00',
#  '2021-12-21 18:00:00-03:00', '2021-12-21 20:00:00-03:00',
#  '2021-12-21 23:00:00-03:00']
# Length: 9, dtype: datetime64[ns, Etc/GMT+3]

# %%
import bifacial_radiance
demo = bifacial_radiance.RadianceObj('Sim')  
weatherfile = r'C:\Users\sayala\Documents\GitHub\Studies\SouthPole\Journals\SouthPole_2021_WeatherFile.csv'
metdata = demo.readWeatherFile(weatherfile, source='SAM')
# Out:
# path = C:\Users\sayala\Documents\GitHub\Studies\SouthPole\Journals
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is left-labeled  with a delta of +30 mins. i.e. 12 is 12:30 sunpos.
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1200: RuntimeWarning: invalid value encountered in remainder
#   H0 = np.degrees(np.arccos(cos_arg)) % 180
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1211: RuntimeWarning: invalid value encountered in remainder
#   m[1] = m[1] % 1
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1212: RuntimeWarning: invalid value encountered in remainder
#   m[2] = m[2] % 1
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1229: RuntimeWarning: invalid value encountered in remainder
#   Hp = (vs + lon - alpha_prime) % 360

# %%
foo2 = pd.DataFrame()
foo2['DNI'] = metdata.dni
foo2['DHI'] = metdata.dhi
foo2['GHI'] = metdata.ghi
foo2['temp_air'] = metdata.temp_air
foo2['wind_speed'] = metdata.wind_speed
foo2['solpos_zenith'] = metdata.solpos.zenith.values
foo2['solpos_azimuth'] = metdata.solpos.azimuth.values
foo2['datetime'] = metdata.datetime
foo2.set_index(foo2.datetime, inplace= True)

# %%
df['DNI'] = np.nan
df['DHI'] = np.nan
df['GHI'] = np.nan
df['temp_air'] = np.nan
df['wind_speed'] = np.nan
df['solpos_zenith'] = np.nan
df['solpos_azimuth'] = np.nan

for ii in range (0, len(uniquetimes)):
    df.loc[df.datetimes == uniquetimes[ii],'DNI'] = foo2.loc[uniquetimes[ii]].DNI
    df.loc[df.datetimes == uniquetimes[ii],'DHI'] = foo2.loc[uniquetimes[ii]].DHI
    df.loc[df.datetimes == uniquetimes[ii],'GHI'] = foo2.loc[uniquetimes[ii]].GHI
    df.loc[df.datetimes == uniquetimes[ii],'temp_air'] = foo2.loc[uniquetimes[ii]].temp_air
    df.loc[df.datetimes == uniquetimes[ii],'wind_speed'] = foo2.loc[uniquetimes[ii]].wind_speed
    df.loc[df.datetimes == uniquetimes[ii],'solpos_zenith'] = foo2.loc[uniquetimes[ii]].solpos_zenith
    df.loc[df.datetimes == uniquetimes[ii],'solpos_azimuth'] = foo2.loc[uniquetimes[ii]].solpos_azimuth

# %% [markdown]
# ## Separate into NS and EW dataframes

# %%
NSG = df.loc[df.Orientation == 'NS'].copy()
EWG = df.loc[df.Orientation == 'EW'].copy()
NSG.head(1)
# Out:
#           Timestamp Orientation Module Row   CH rtr  \
# 25  2021-12-21_0200          NS     00  00  0.6   8
#
#                                                     x  \
# 25  [4.397143, 4.397143, 4.397143, 4.397143, 4.397...
#
#                                                     y  \
# 25  [15.979, 15.979, 15.979, 15.979, 15.979, 15.97...
#
#                                                     z  \
# 25  [2.4, 2.2, 2.0, 1.8, 1.6, 1.4, 1.2, 1.0, 0.8, ...
#
#                                                 rearZ  ...  \
# 25  [2.4, 2.2, 2.0, 1.8, 1.6, 1.4, 1.2, 1.0, 0.8, ...  ...
#
#                                              Wm2Front  \
# 25  [408.4412, 408.4467, 408.4482, 409.5804, 409.3...
#
#                                               Wm2Back  \
# 25  [172.2435, 171.8309, 171.4175, 171.4135, 170.9...
#
#                    datetimes         DNI         DHI      GHI  temp_air  \
# 25 2021-12-21 02:00:00-03:00  362.523333  172.871667  408.295   -18.945
#
#     wind_speed  solpos_zenith  solpos_azimuth
# 25    7.861667      66.576061      121.812315
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Sort Values by Date, Row and Module

# %%
NSG = NSG.sort_values(['datetimes', 'Row', 'Module'],
              ascending = [True, True, True])
EWG = EWG.sort_values(['datetimes', 'Row', 'Module'],
              ascending = [True, True, True])

# %% [markdown]
# ## Calculate POAs

# %%
Wm2Front = pd.DataFrame(item for item in NSG['Wm2Front'])
Wm2Back = pd.DataFrame(item for item in NSG['Wm2Back'])

NSG['SouthFacing_POA'] = (Wm2Front+Wm2Back*0.6).mean(axis=1).values
NSG['NorthFacing_POA'] = (Wm2Front*0.6+Wm2Back).mean(axis=1).values
NSG.SouthFacing_POA

Wm2Front = pd.DataFrame(item for item in EWG['Wm2Front'])
Wm2Back = pd.DataFrame(item for item in EWG['Wm2Back'])
EWG['EastFacing_POA'] = (Wm2Front+Wm2Back*0.6).mean(axis=1).values
EWG['WestFacing_POA'] = (Wm2Front*0.6+Wm2Back).mean(axis=1).values

# %% [markdown]
# ## Asign CEC module

# %%
import pvlib 
CECMODS = pvlib.pvsystem.retrieve_sam('CECMod')
INVERTERS = pvlib.pvsystem.retrieve_sam('CECInverter')

CECMOD_CSI = CECMODS['Canadian_Solar_Inc__CS6X_300P']

# %% [markdown]
# ## Calculate Performances

# %%
NSG['North_Performance'] = bifacial_radiance.performance.calculatePerformance(effective_irradiance = NSG['NorthFacing_POA'], CECMod = CECMOD_CSI,
                                                  temp_air = NSG['temp_air'],
                                                  wind_speed = NSG['wind_speed'],
                                                  glassglass=True)

NSG['South_Performance'] = bifacial_radiance.performance.calculatePerformance(effective_irradiance = NSG['SouthFacing_POA'], CECMod = CECMOD_CSI,
                                                  temp_air = NSG['temp_air'],
                                                  wind_speed = NSG['wind_speed'],
                                                  glassglass=True)

EWG['East_Performance'] = bifacial_radiance.performance.calculatePerformance(effective_irradiance = EWG['EastFacing_POA'], CECMod = CECMOD_CSI,
                                                  temp_air = EWG['temp_air'],
                                                  wind_speed = EWG['wind_speed'],
                                                  glassglass=True)

EWG['West_Performance'] = bifacial_radiance.performance.calculatePerformance(effective_irradiance = EWG['WestFacing_POA'], CECMod = CECMOD_CSI,
                                                  temp_air = EWG['temp_air'],
                                                  wind_speed = EWG['wind_speed'],
                                                  glassglass=True)

# %%
# UGLY MAPPING

#x=range(0,len(NSG['NorthFacing_POA']))
#plt.figure(figsize=(18, 6), dpi=80)

#plt.plot(x,  NSG['NorthFacing_POA'], label='North')
#plt.plot(x, NSG['SouthFacing_POA'], label='South')
#x=range(0,len(EWG['EastFacing_POA']))
#plt.plot(x,  EWG['EastFacing_POA'], label='East')
#plt.plot(x, EWG['WestFacing_POA'], 'y', label='West')
#plt.plot(range(45,80), np.ones(80-45)*1286, '.r', label='VF SouthFacing')
#plt.plot(range(85,120), np.ones(120-85)*1495,  '.r')
#plt.plot(range(120,160), np.ones(160-120)*1664,  '.r')
#plt.plot(range(165,190), np.ones(190-165)*1602, '.r')
#plt.plot(range(200,240), np.ones(240-200)*1470, '.r')
#plt.plot(range(250,280), np.ones(280-250)*1193, '.r')
#plt.plot(range(290,310), np.ones(310-290)*531, '.r')
#plt.plot(range(320,360), np.ones(360-320)*449, '.r')
#plt.ylabel("Irradiance [W/m$^2$]")
#plt.legend(loc='lower center', ncol=3)

# %% [markdown]
# ## WORKING WITH 2021-02-21_0200

# %%
Wm2Front = pd.DataFrame(item for item in NSG[NSG['Timestamp'] == '2021-12-21_0500']['Wm2Front'])
Wm2Back = pd.DataFrame(item for item in NSG[NSG['Timestamp'] == '2021-12-21_0500']['Wm2Back'])
SouthF = (Wm2Front+Wm2Back*0.6)
NorthF = (Wm2Front*0.6+Wm2Back)

Wm2Front = pd.DataFrame(item for item in EWG[EWG['Timestamp'] == '2021-12-21_0500']['Wm2Front'])
Wm2Back = pd.DataFrame(item for item in EWG[EWG['Timestamp'] == '2021-12-21_0500']['Wm2Back'])
EastF = (Wm2Front+Wm2Back*0.6)
WestF = (Wm2Front*0.6+Wm2Back)

# %%
NorthF
# Out:
#             0           1           2           3           4           5   \
# 0   1314.68226  1312.30760  1309.96960  1307.71246  1303.55236  1304.05946
# 1   1305.23716  1301.70820  1298.21348  1295.66258  1290.94054  1290.06144
# 2   1282.56062  1278.15538  1273.88958  1269.93564  1263.71870  1261.27926
# 3   1283.50002  1279.10234  1274.73616  1271.81296  1265.31144  1260.98730
# 4   1290.08088  1285.53648  1281.02310  1276.82948  1270.31616  1267.14002
# 5   1268.16726  1265.81902  1263.50926  1259.50480  1256.82548  1254.18362
# 6   1247.22200  1244.75042  1242.31498  1239.95062  1235.40146  1234.88158
# 7   1211.14688  1206.67342  1202.22970  1200.60524  1194.79180  1189.59908
# 8   1213.04644  1208.76944  1204.52902  1198.17660  1192.41898  1188.68566
# 9   1224.01146  1220.01566  1216.05298  1210.72326  1205.76674  1198.69980
# 10  1263.41134  1260.91506  1258.42616  1261.76938  1258.47496  1255.65554
# 11  1245.40666  1242.37918  1239.37322  1239.07544  1235.69702  1230.97872
# 12  1209.90096  1205.77792  1201.66998  1198.95710  1193.16712  1185.36084
# 13  1215.39398  1210.97510  1206.56958  1199.21168  1193.65840  1186.94518
# 14  1220.28234  1216.58572  1212.89936  1208.37350  1202.03970  1195.01028
# 15  1263.25150  1260.43208  1257.64318  1261.91930  1258.90788  1256.07954
# 16  1245.70668  1242.94696  1240.22840  1237.36348  1233.58248  1235.84434
# 17  1209.04612  1204.61978  1200.22886  1198.61342  1193.09872  1192.03450
# 18  1211.45638  1206.72044  1202.02264  1198.62460  1192.27872  1189.53598
# 19  1222.36134  1217.94542  1213.55892  1209.78908  1202.70816  1197.43528
# 20  1292.48680  1289.49434  1286.53766  1293.47000  1290.14248  1288.09882
# 21  1280.97500  1277.38336  1273.82648  1272.46238  1268.11822  1265.14210
# 22  1253.22596  1249.13428  1245.48490  1241.96440  1236.70642  1229.97576
# 23  1251.01544  1246.59500  1243.34358  1239.01734  1233.56724  1227.56520
# 24  1260.06392  1255.69312  1251.55330  1243.96774  1237.70960  1230.01912
#
#             6           7           8           9   ...          44  \
# 0   1302.01732  1300.67124  1296.21068  1313.29684  ...  1286.46242
# 1   1282.72180  1280.68714  1270.96608  1304.10964  ...  1266.16352
# 2   1252.78048  1248.57938  1236.88896  1282.36642  ...  1238.79752
# 3   1252.13354  1247.29280  1235.12082  1283.89636  ...  1241.22118
# 4   1258.70848  1253.84750  1241.57186  1290.73540  ...  1253.45962
# 5   1259.04624  1254.40026  1260.96016  1266.22804  ...  1237.76912
# 6   1229.50874  1233.16108  1225.54078  1245.30214  ...  1209.98546
# 7   1182.06394  1182.94002  1173.10656  1210.30244  ...  1165.30138
# 8   1180.49992  1175.38178  1162.73826  1213.65806  ...  1172.68954
# 9   1189.94270  1186.48504  1174.93674  1225.33262  ...  1185.64020
# 10  1255.18222  1252.58278  1251.81832  1261.29890  ...  1235.18256
# 11  1231.02402  1226.58954  1226.62020  1243.40074  ...  1209.98242
# 12  1177.55480  1174.13848  1164.00636  1209.11474  ...  1163.97452
# 13  1178.09482  1171.10320  1167.93876  1216.10334  ...  1172.05958
# 14  1186.86086  1187.38334  1176.27950  1221.37274  ...  1185.33904
# 15  1255.95082  1253.31536  1253.31002  1261.53046  ...  1236.24480
# 16  1230.77884  1230.16634  1222.12710  1243.93130  ...  1209.85224
# 17  1185.36706  1180.08010  1169.32442  1208.32896  ...  1168.00690
# 18  1181.01004  1178.78052  1166.90846  1212.31606  ...  1172.31176
# 19  1188.09318  1184.48380  1172.67168  1223.79308  ...  1186.44666
# 20  1283.42752  1280.57206  1278.44270  1290.98286  ...  1266.15578
# 21  1264.27668  1259.54704  1254.71636  1279.38856  ...  1240.58370
# 22  1223.57626  1219.59712  1210.36220  1252.56210  ...  1204.24526
# 23  1219.67134  1210.35788  1200.56722  1251.44260  ...  1206.34074
# 24  1231.20830  1221.01598  1213.12446  1260.72554  ...  1214.11784
#
#             45          46          47          48          49          50  \
# 0   1306.99684  1304.01036  1301.02378  1301.89708  1297.41486  1295.32354
# 1   1299.73684  1295.30724  1290.58370  1290.50820  1284.83908  1280.22528
# 2   1279.99898  1277.12290  1274.57108  1270.29324  1264.96918  1259.47816
# 3   1287.18436  1284.47156  1278.81114  1275.36648  1273.24984  1265.42114
# 4   1294.49262  1293.66096  1288.63472  1283.06388  1281.76736  1274.51090
# 5   1254.33774  1251.13644  1247.84488  1248.48634  1245.41474  1241.90804
# 6   1237.39560  1234.67692  1230.57702  1227.05964  1221.85022  1219.85860
# 7   1208.84840  1204.14096  1200.91882  1195.41920  1190.20276  1185.55542
# 8   1218.07384  1213.55720  1209.04632  1203.67446  1200.84390  1195.54504
# 9   1230.98458  1228.22196  1225.44494  1220.03348  1212.37894  1211.14054
# 10  1250.06718  1247.02414  1243.98100  1249.13446  1246.66674  1243.23876
# 11  1235.92160  1233.41680  1229.78340  1225.02134  1225.75474  1221.59338
# 12  1206.03016  1201.85252  1196.95086  1193.31312  1189.89276  1185.08352
# 13  1218.07764  1214.28622  1211.93298  1206.47634  1200.99806  1195.72360
# 14  1225.77566  1223.13456  1219.74366  1215.27682  1209.98202  1208.85284
# 15  1252.96342  1250.02224  1247.08096  1245.77762  1245.65980  1241.78654
# 16  1235.89544  1230.01740  1226.91646  1229.00520  1224.99740  1221.60244
# 17  1205.92802  1204.23224  1200.61882  1196.36444  1190.81330  1189.83764
# 18  1216.20296  1211.73632  1211.11608  1207.29634  1201.79862  1195.55668
# 19  1230.27756  1226.92568  1222.91520  1217.64896  1212.02794  1204.13506
# 20  1285.31294  1282.20268  1279.09238  1281.76538  1278.27972  1274.93306
# 21  1270.86824  1266.96856  1263.06866  1259.63636  1260.90938  1257.10560
# 22  1249.72446  1245.52092  1241.66982  1238.31870  1234.64882  1228.09832
# 23  1253.29930  1250.45682  1247.87220  1242.22460  1236.71022  1234.28654
# 24  1263.51160  1260.12472  1258.92558  1253.12452  1245.57630  1238.62554
#
#             51          52          53
# 0   1292.60962  1286.81472  1285.93010
# 1   1274.57974  1266.68496  1263.04400
# 2   1251.24996  1240.73322  1238.14392
# 3   1256.99328  1247.02306  1240.83800
# 4   1266.50474  1260.73440  1252.52016
# 5   1244.84110  1239.30858  1233.47172
# 6   1217.47918  1211.01922  1208.76088
# 7   1180.06986  1173.83560  1164.71424
# 8   1189.24346  1179.57642  1173.57836
# 9   1203.48700  1194.10354  1187.17204
# 10  1239.99846  1234.96100  1228.26688
# 11  1216.92082  1212.60202  1206.87050
# 12  1182.84192  1172.42204  1163.49172
# 13  1188.43598  1179.04646  1173.53316
# 14  1200.69760  1190.35698  1184.69482
# 15  1241.00892  1238.85290  1231.12722
# 16  1217.90034  1211.10786  1206.59004
# 17  1181.97148  1173.23768  1167.05658
# 18  1185.72756  1175.58084  1173.36796
# 19  1196.30084  1189.54646  1187.82276
# 20  1274.79656  1268.04944  1260.35144
# 21  1250.83074  1246.34254  1236.49980
# 22  1219.23554  1212.36772  1203.00008
# 23  1223.80696  1213.86496  1209.35336
# 24  1235.24650  1226.96162  1215.67292
#
# [25 rows x 54 columns]

# %%
ii = 0
arrayallN = pd.DataFrame()
arrayallS = pd.DataFrame()
arrayallE = pd.DataFrame()
arrayallW = pd.DataFrame()

for rr in range (0, 5):
    rowallN = pd.DataFrame()
    rowallS = pd.DataFrame()
    rowallE = pd.DataFrame()
    rowallW = pd.DataFrame()

    for mm in range (0, 5):
        # North
        my_list = NorthF.loc[ii]
        my_list = pd.DataFrame(np.array(my_list).reshape(6,9)).T
        rowallN = pd.concat([rowallN, my_list], axis=1)
        # South
        my_list = SouthF.loc[ii]
        my_list = pd.DataFrame(np.array(my_list).reshape(6,9)).T
        rowallS = pd.concat([rowallS, my_list], axis=1)
        # East
        my_list = EastF.loc[ii]
        my_list = pd.DataFrame(np.array(my_list).reshape(6,9)).T
        rowallE = pd.concat([rowallE, my_list], axis=1)
        # West
        my_list = WestF.loc[ii]
        my_list = pd.DataFrame(np.array(my_list).reshape(6,9)).T
        rowallW = pd.concat([rowallW, my_list], axis=1)
        ii += 1
    arrayallN = pd.concat([arrayallN, rowallN], axis=0, sort=False, ignore_index=True)
    arrayallS = pd.concat([arrayallS, rowallS], axis=0, sort=False, ignore_index=True)
    arrayallE = pd.concat([arrayallE, rowallE], axis=0, sort=False, ignore_index=True)
    arrayallW = pd.concat([arrayallW, rowallW], axis=0, sort=False, ignore_index=True)

# %%
maxmax = np.max([arrayallN.max().max(),
arrayallS.max().max(),
arrayallE.max().max(),
arrayallW.max().max()])

minmin = np.min([arrayallN.min().min(),
arrayallS.min().min(),
arrayallE.min().min(),
arrayallW.min().min()])

print("Max Irradiance in the 4 arrays: ", np.round(maxmax))
print("Min Irradiance in the 4 arrays: ", np.round(minmin))
# Out:
# Max Irradiance in the 4 arrays:  1748.0
# Min Irradiance in the 4 arrays:  1092.0

# %%
# Printing POA_t (Gfront + Grear*bifaciality)) on each Cell

plt.rcParams.update({'font.size': 22})
plt.rcParams['figure.figsize'] = (12, 8)

df = arrayallN

with sns.axes_style("white"):
    fig = plt.imshow(df, cmap='hot', vmin=minmin, vmax=maxmax, interpolation='none', aspect = 0.4)
    plt.colorbar(label='POA Irradiance W/m$^2}$')
    #plt.title('Yearly Bifacial, in matrix form')
    fig.axes.get_yaxis().set_visible(False)
    fig.axes.get_xaxis().set_visible(False)
plt.title("North")    
plt.show()

plt.figure()

df = arrayallS


with sns.axes_style("white"):
    fig = plt.imshow(df, cmap='hot', vmin=minmin, vmax=maxmax, interpolation='none', aspect = 0.4)
    plt.colorbar(label='POA Irradiance W/m$^2}$')
    #plt.title('Yearly Bifacial, in matrix form')
    fig.axes.get_yaxis().set_visible(False)
    fig.axes.get_xaxis().set_visible(False)
plt.title("South")        
plt.show()

plt.figure()

df = arrayallE


with sns.axes_style("white"):
    fig = plt.imshow(df, cmap='hot', vmin=minmin, vmax=maxmax, interpolation='none', aspect = 0.4)
    plt.colorbar(label='POA Irradiance W/m$^2}$')
    #plt.title('Yearly Bifacial, in matrix form')
    fig.axes.get_yaxis().set_visible(False)
    fig.axes.get_xaxis().set_visible(False)
plt.title("East")        
plt.show()

plt.figure()

df = arrayallW

with sns.axes_style("white"):
    fig = plt.imshow(df, cmap='hot', vmin=minmin, vmax=maxmax, interpolation='none', aspect = 0.4)
    plt.colorbar(label='POA Irradiance W/m$^2}$')
    #plt.title('Yearly Bifacial, in matrix form')
    fig.axes.get_yaxis().set_visible(False)
    fig.axes.get_xaxis().set_visible(False)
plt.title("West")        
plt.show()

# %% [markdown]
# # MAP PERFORMANCES

# %%
ii = 0
PowerallN = []
PowerallS = []
PowerallE = []
PowerallW = []

for rr in range (0, 4):
    rowallN = []
    rowallS = []
    rowallE = []
    rowallW = []

    for mm in range (0, 10):
        ii += 1
        rowallN.append(NSG['North_Performance'].iloc[ii])
        rowallS.append(NSG['South_Performance'].iloc[ii])
        rowallE.append(EWG['East_Performance'].iloc[ii])
        rowallW.append(EWG['West_Performance'].iloc[ii])

    PowerallN.append(rowallN)
    PowerallS.append(rowallS)
    PowerallE.append(rowallE)
    PowerallW.append(rowallW)

PowerallN = pd.DataFrame(PowerallN)
PowerallS = pd.DataFrame(PowerallS)
PowerallE = pd.DataFrame(PowerallE)
PowerallW = pd.DataFrame(PowerallW)

# %%
A = [PowerallN.max().max(),
PowerallS.max().max(),
PowerallE.max().max(),
PowerallW.max().max()]

B = [PowerallN.min().min(),
PowerallS.min().min(),
PowerallE.min().min(),
PowerallW.min().min()]

print("Power Mismatch in each array", np.round(np.subtract(A, B)*100/A), '%')
print("Max Module Power in each array", np.round(A), 'W')
print("Min Module Power in each array", np.round(B), 'W')
# Out:
# Power Mismatch in each array [68. 57. 58. 64.] %
# Max Module Power in each array [402. 381. 498. 433.] W
# Min Module Power in each array [129. 165. 208. 155.] W

# %%
nameplate_array = 300*40
print("Power Array Nameplate ", np.round(nameplate_array/1000,1), " kW")
print("Power Array N S E W ", np.round(np.multiply(B,40/1000),1), " kW")
print("PR Array N S E W", np.round(np.multiply(B,40/nameplate_array),2))
# Out:
# Power Array Nameplate  12.0  kW
# Power Array N S E W  [5.1 6.6 8.3 6.2]  kW
# PR Array N S E W [0.43 0.55 0.69 0.52]

# %%
# Printing Timestamp Data
print(NSG.iloc[30]['Timestamp'])
print("--------------------------")
print("solpos_zenith", np.round(NSG.iloc[0]['solpos_zenith'],1))
print("solpos_azimuth", np.round(NSG.iloc[0]['solpos_azimuth'],1))
print("DNI", np.round(NSG.iloc[0]['DNI'],1))
print("DHI", np.round(NSG.iloc[0]['DHI'],1))
print("GHI", np.round(NSG.iloc[0]['GHI'],1))
print("wind_speed", np.round(NSG.iloc[0]['wind_speed'],1))
print("temp_air", np.round(NSG.iloc[0]['temp_air'],1))
# Out:
# 2021-12-21_0500
# --------------------------
# solpos_zenith 66.6
# solpos_azimuth 121.8
# DNI 362.5
# DHI 172.9
# GHI 408.3
# wind_speed 7.9
# temp_air -18.9

# %%
# Plotting Performance
df = PowerallN
maxmax = np.max(A)
minmin = np.min(B)

plt.rcParams.update({'font.size': 22})
plt.rcParams['figure.figsize'] = (12, 8)


with sns.axes_style("white"):
    fig = plt.imshow(df, cmap='hot', vmin=minmin, vmax=maxmax, interpolation='none', aspect = 1.5)
    plt.colorbar(label='Power [W/m$^2$]')
    #plt.title('Yearly Bifacial, in matrix form')
    fig.axes.get_yaxis().set_visible(False)
    fig.axes.get_xaxis().set_visible(False)
plt.title("North")   
plt.show()

plt.figure()

df = PowerallS

plt.rcParams.update({'font.size': 22})
plt.rcParams['figure.figsize'] = (12, 8)


with sns.axes_style("white"):
    fig = plt.imshow(df, cmap='hot', vmin=minmin, vmax=maxmax, interpolation='none', aspect =  1.5)
    plt.colorbar(label='Power [W/m$^2$]')
    #plt.title('Yearly Bifacial, in matrix form')
    fig.axes.get_yaxis().set_visible(False)
    fig.axes.get_xaxis().set_visible(False)
plt.title("South")   

plt.show()

plt.figure()

df = PowerallE

plt.rcParams.update({'font.size': 22})
plt.rcParams['figure.figsize'] = (12, 8)


with sns.axes_style("white"):
    fig = plt.imshow(df, cmap='hot', vmin=minmin, vmax=maxmax, interpolation='none', aspect =  1.5)
    plt.colorbar(label='Power [W/m$^2$]')
    #plt.title('Yearly Bifacial, in matrix form')
    fig.axes.get_yaxis().set_visible(False)
    fig.axes.get_xaxis().set_visible(False)
plt.title("East")   

plt.show()

plt.figure()

df = PowerallW

plt.rcParams.update({'font.size': 22})
plt.rcParams['figure.figsize'] = (12, 8)


with sns.axes_style("white"):
    fig = plt.imshow(df, cmap='hot', vmin=minmin, vmax=maxmax, interpolation='none', aspect =  1.5)
    plt.colorbar(label='Power [W/m$^2$]')
    #plt.title('Yearly Bifacial, in matrix form')
    fig.axes.get_yaxis().set_visible(False)
    fig.axes.get_xaxis().set_visible(False)
plt.title("West")   
plt.show()
