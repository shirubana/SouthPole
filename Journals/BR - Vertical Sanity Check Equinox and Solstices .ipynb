# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
import bifacial_radiance
import bifacialvf
print(bifacialvf.__version__)
print(bifacial_radiance.__version__)
# Out:
# 0.1.7-dev1+73.gf25ac0f.dirty
# 0.4.1+121.g952f921.dirty

# %%
testfolder = r'TEMP\RADIANCE'
if not os.path.exists(testfolder):
    os.makedirs(testfolder)

# %%
# LOOP
pitchs = [2, 3, 5] 
CHs = [0.3, 0.5, 0.75, 1.0]
albs = [0.22, 0.8]
locs = [722740, 727930 ]
locsnames = ['Tucson', 'Seattle']

# %%
demo = bifacial_radiance.RadianceObj('Sim', path=testfolder)
# Out:
# path = TEMP\RADIANCE
# Making path: images
# Making path: objects
# Making path: results
# Making path: skies
# Making path: EPWs
# Making path: materials

# %%
deltastyle = 'SAM'  # 
tilt = 90                   # PV tilt (deg)
sazm = 180                  # PV Azimuth(deg) or tracker axis direction
albedo = 0.80               # ground albedo
clearance_height = 0.5
pitch = 3                   # row to row spacing in normalized panel lengths. 
rowType = "interior"        # RowType(first interior last single)
transFactor = 0.013         # TransmissionFactor(open area fraction)
sensorsy = 12                # sensorsy(# hor rows in panel)   <--> THIS ASSUMES LANDSCAPE ORIENTATION 
PVfrontSurface = "glass"    # PVfrontSurface(glass or ARglass)
PVbackSurface = "glass"     # PVbackSurface(glass or ARglass)

# Calculate PV Output Through Various Methods    
# This variables are advanced and explored in other tutorials.
#calculateBilInterpol = True         # Only works with landscape at the moment.
#calculatePVMismatch = True
#portraitorlandscape='landscape'   # portrait or landscape
#cellsnum = 72
#bififactor = 1.0
#agriPV = True                       # Returns ground irradiance values

# Tracking instructions
tracking=False
backtrack=False
limit_angle = 60

sazmNS = 180                  # PV Azimuth(deg) or tracker axis direction
sazmEW = 90                  # PV Azimuth(deg) or tracker axis direction

cumulativesky = False

startdate = ['03_21', '06_21', '12_21']

for idx in startdate:
    for ii in range(0, len(locs)):
        for jj in range(0, len(albs)):
            for zz in range(0, len(CHs)):
                for ww in range(0, len(pitchs)):

                    loc = locs[ii]
                    locname = locsnames[ii]
                    albedo = albs[jj]
                    clearance_height = CHs[zz]
                    pitch = pitchs[ww]
                    gcr = 2/pitch
                    weatherfile = r'C:\Users\sayala\Desktop\VERTICAL\{}TYA.CSV'.format(loc)
                    writefiletitle = 'NS_'+locname+'_Alb_'+str(albedo)+'_CH_'+str(clearance_height)+'_rtr_'+str(pitch)+'.csv'
                    
                    demo.setGround(albedo) 
                    metdata = demo.readWeatherFile(weatherfile, starttime=idx, endtime=idx)  
                    mymodule = bifacial_radiance.ModuleObj(name='PVmodw', x=1, y=2)
                    sceneDict = {'pitch':pitch,'hub_height':clearance_height, 'nMods': 20, 'nRows': 7, 'azimuth': sazmNS}  
                    demo.set1axis(limit_angle = limit_angle, backtrack = backtrack, gcr=gcr, cumulativesky = cumulativesky,
                                 fixed_tilt_angle=90, azimuth=sazmNS)
                    demo.gendaylit1axis()
                    demo.makeScene1axis(module=mymodule,sceneDict=sceneDict) #makeScene creates a .rad file with 20 modules per row, 7 rows.
                    demo.makeOct1axis()
                    demo.analysis1axis(customname=writefiletitle)
                    
                    
                    writefiletitle = 'EW_'+locname+'_Alb_'+str(albedo)+'_CH_'+str(clearance_height)+'_rtr_'+str(pitch)+'.csv'

                    sceneDict = {'pitch':pitch,'hub_height':clearance_height, 'nMods': 20, 'nRows': 7, 'azimuth': sazmEW} 
                    demo.set1axis(limit_angle = limit_angle, backtrack = backtrack, gcr=gcr, cumulativesky = cumulativesky,
                                 fixed_tilt_angle=90, azimuth=sazmEW)
                    demo.gendaylit1axis()
                    demo.makeScene1axis(module=mymodule,sceneDict=sceneDict) #makeScene creates a .rad file with 20 modules per row, 7 rows.
                    demo.makeOct1axis()
                    demo.analysis1axis(customname=writefiletitle)
# Out:
# Loading albedo, 1 value(s), 0.220 avg
# 1 nonzero albedo values.
# Warning: CSV file passed for input. Assuming it is TMY3style format
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
#
# Module Name: PVmodw
# Module PVmodw updated in module.json
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 73.46085333333332. Wm2Back: 9.932376
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 196.54539666666668. Wm2Back: 20.97161
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 311.18213000000003. Wm2Back: 29.45375
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 415.85067888888887. Wm2Back: 43.55584000000001
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 485.8482333333334. Wm2Back: 55.08325
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 509.6185. Wm2Back: 65.50858
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 495.12344444444443. Wm2Back: 65.49588
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 444.54839999999996. Wm2Back: 64.40116
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 357.6685677777778. Wm2Back: 57.61826
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1700. Wm2Front: 238.4064633333333. Wm2Back: 37.8422
# Linescan in process: 1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1800. Wm2Front: 113.11772555555554. Wm2Back: 22.06578
# Linescan in process: 1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1900. Wm2Front: 9.192913444444445. Wm2Back: 7.030052
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 13.4867. Wm2Back: 13.277141333333333
# Linescan in process: 1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 26.09205. Wm2Back: 32.09870222222222
# Linescan in process: 1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 32.87639. Wm2Back: 51.42376111111111
# Linescan in process: 1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 44.08952. Wm2Back: 79.62027333333333
# Linescan in process: 1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 49.73087999999999. Wm2Back: 108.91944222222223
# Linescan in process: 1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 54.95972. Wm2Back: 140.85746666666668
# Linescan in process: 1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 57.78929. Wm2Back: 317.5163111111111
# Linescan in process: 1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 66.38398. Wm2Back: 475.93005555555555
# Linescan in process: 1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 78.25478. Wm2Back: 587.1387611111111
# Linescan in process: 1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1700. Wm2Front: 81.81181. Wm2Back: 613.2915577777778
# Linescan in process: 1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1800. Wm2Front: 104.10769999999998. Wm2Back: 534.9656155555555
# Linescan in process: 1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1900. Wm2Front: 50.84646999999999. Wm2Back: 166.75446177777778
# Loading albedo, 1 value(s), 0.220 avg
# 1 nonzero albedo values.
# Warning: CSV file passed for input. Assuming it is TMY3style format
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
#
# Module Name: PVmodw
# Module PVmodw updated in module.json
# Pre-existing .rad file objects\PVmodw.rad will be overwritten
#
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 73.44210111111111. Wm2Back: 9.932376
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 196.59583666666666. Wm2Back: 20.97161
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 311.09515444444446. Wm2Back: 29.45375
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 415.80022444444444. Wm2Back: 43.55584000000001
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 485.76606666666675. Wm2Back: 55.08325
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 509.6025111111111. Wm2Back: 65.50858
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 495.08753333333334. Wm2Back: 65.49588
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 444.5912333333333. Wm2Back: 64.40116
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 357.5915122222222. Wm2Back: 57.61826
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1700. Wm2Front: 238.32734555555555. Wm2Back: 37.8422
# Linescan in process: 1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1800. Wm2Front: 113.07916111111112. Wm2Back: 22.06578
# Linescan in process: 1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1900. Wm2Front: 9.196816888888888. Wm2Back: 7.030052
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 13.4867. Wm2Back: 13.287288222222223
# Linescan in process: 1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 26.09205. Wm2Back: 32.115183333333334
# Linescan in process: 1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 32.87639. Wm2Back: 51.39416777777777
# Linescan in process: 1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 44.08952. Wm2Back: 79.68176999999999
# Linescan in process: 1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 49.73087999999999. Wm2Back: 108.98119666666666
# Linescan in process: 1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 54.95972. Wm2Back: 140.8856
# Linescan in process: 1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 57.78929. Wm2Back: 317.72148888888887
# Linescan in process: 1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 66.38398. Wm2Back: 475.9478555555556
# Linescan in process: 1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 78.25478. Wm2Back: 587.1214711111111
# Linescan in process: 1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1700. Wm2Front: 81.81181. Wm2Back: 613.3381199999999
# Linescan in process: 1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1800. Wm2Front: 104.10769999999998. Wm2Back: 535.07692
# Linescan in process: 1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1900. Wm2Front: 50.84646999999999. Wm2Back: 166.7583008888889
# Loading albedo, 1 value(s), 0.220 avg
# 1 nonzero albedo values.
# Warning: CSV file passed for input. Assuming it is TMY3style format
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
#
# Module Name: PVmodw
# Module PVmodw updated in module.json
# Pre-existing .rad file objects\PVmodw.rad will be overwritten
#
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 73.45196555555555. Wm2Back: 9.932376
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 196.5375788888889. Wm2Back: 20.97161
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 311.15146666666664. Wm2Back: 29.45375
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 415.7845066666667. Wm2Back: 43.55584000000001
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 485.71900000000005. Wm2Back: 55.08325
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 509.62567777777775. Wm2Back: 65.50858
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 495.166511111111. Wm2Back: 65.49588
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 444.6254333333334. Wm2Back: 64.40116
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 357.6333322222223. Wm2Back: 57.61826
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1700. Wm2Front: 238.30339111111113. Wm2Back: 37.8422
# Linescan in process: 1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1800. Wm2Front: 113.13843666666668. Wm2Back: 22.06578
# Linescan in process: 1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1900. Wm2Front: 9.231567666666669. Wm2Back: 7.030052
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 13.4867. Wm2Back: 13.280225666666668
# Linescan in process: 1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 26.09205. Wm2Back: 32.10528
# Linescan in process: 1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 32.87639. Wm2Back: 51.37602777777777
# Linescan in process: 1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 44.08952. Wm2Back: 79.55711777777778
# Linescan in process: 1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 49.73087999999999. Wm2Back: 108.88759333333333
# Linescan in process: 1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 54.95972. Wm2Back: 140.81617777777777
# Linescan in process: 1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 57.78929. Wm2Back: 317.6455888888888
# Linescan in process: 1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 66.38398. Wm2Back: 476.0417444444445
# Linescan in process: 1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 78.25478. Wm2Back: 587.1155755555556
# Linescan in process: 1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1700. Wm2Front: 81.81181. Wm2Back: 613.3932244444444
# Linescan in process: 1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1800. Wm2Front: 104.10769999999998. Wm2Back: 535.0101733333335
# Linescan in process: 1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.3_rtr_5.csv_Row10_Module10.csv
# Index: 2021-03-21_1900. Wm2Front: 50.84646999999999. Wm2Back: 166.78637644444447
# Loading albedo, 1 value(s), 0.220 avg
# 1 nonzero albedo values.
# Warning: CSV file passed for input. Assuming it is TMY3style format
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
#
# Module Name: PVmodw
# Module PVmodw updated in module.json
# Pre-existing .rad file objects\PVmodw.rad will be overwritten
#
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 82.56140666666667. Wm2Back: 9.932376
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 221.41539444444444. Wm2Back: 20.97161
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 350.6723711111111. Wm2Back: 29.45375
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 468.7415911111111. Wm2Back: 43.55584000000001
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 547.8476222222221. Wm2Back: 55.08325
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 574.6637888888888. Wm2Back: 65.50858
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 558.2328666666667. Wm2Back: 65.49588
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 500.9475555555555. Wm2Back: 64.40116
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 402.46591. Wm2Back: 57.61826
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1700. Wm2Front: 268.6737266666667. Wm2Back: 37.8422
# Linescan in process: 1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1800NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1800. Wm2Front: 127.37730555555555. Wm2Back: 22.06578
# Linescan in process: 1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1900NS_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1900. Wm2Front: 9.966149333333332. Wm2Back: 7.030052
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 13.4867. Wm2Back: 12.427224555555556
# Linescan in process: 1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 26.09205. Wm2Back: 29.59101
# Linescan in process: 1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 32.87639. Wm2Back: 47.72519
# Linescan in process: 1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 44.08952. Wm2Back: 76.69197
# Linescan in process: 1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 49.73087999999999. Wm2Back: 108.05836333333332
# Linescan in process: 1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 54.95972. Wm2Back: 144.5119222222222
# Linescan in process: 1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 57.78929. Wm2Back: 351.3251
# Linescan in process: 1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 66.38398. Wm2Back: 537.6807
# Linescan in process: 1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 78.25478. Wm2Back: 670.1983911111112
# Linescan in process: 1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1700EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1700. Wm2Front: 81.81181. Wm2Back: 706.1280677777778
# Linescan in process: 1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1800EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1800. Wm2Front: 104.10769999999998. Wm2Back: 619.2229866666667
# Linescan in process: 1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1900EW_Tucson_Alb_0.22_CH_0.5_rtr_2.csv_Row10_Module10.csv
# Index: 2021-03-21_1900. Wm2Front: 50.84646999999999. Wm2Back: 193.43596233333335
# Loading albedo, 1 value(s), 0.220 avg
# 1 nonzero albedo values.
# Warning: CSV file passed for input. Assuming it is TMY3style format
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
#
# Module Name: PVmodw
# Module PVmodw updated in module.json
# Pre-existing .rad file objects\PVmodw.rad will be overwritten
#
# Creating ~13 skyfiles.
# Warning: negative sun elevation at 2021-03-21 19:00:00-07:00.  Re-calculated elevation: 6.9
# Created 13 skyfiles in /skies/
#
# Making ~13 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 13 Radfiles created in /objects/
#
# Making 13 octfiles in root directory.
# Missing files, skipping...
# Created 1axis_2021-03-21_0800.oct
# Created 1axis_2021-03-21_0900.oct
# Created 1axis_2021-03-21_1000.oct
# Created 1axis_2021-03-21_1100.oct
# Created 1axis_2021-03-21_1200.oct
# Created 1axis_2021-03-21_1300.oct
# Created 1axis_2021-03-21_1400.oct
# Created 1axis_2021-03-21_1500.oct
# Created 1axis_2021-03-21_1600.oct
# Created 1axis_2021-03-21_1700.oct
# Created 1axis_2021-03-21_1800.oct
# Created 1axis_2021-03-21_1900.oct
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0800NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_0800. Wm2Front: 82.61007000000001. Wm2Back: 9.932376
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_0900NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_0900. Wm2Front: 221.42674777777776. Wm2Back: 20.97161
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1000NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1000. Wm2Front: 350.6594533333334. Wm2Back: 29.45375
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1100NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1100. Wm2Front: 468.66515666666663. Wm2Back: 43.55584000000001
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1200NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1200. Wm2Front: 547.7216333333333. Wm2Back: 55.08325
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1300NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1300. Wm2Front: 574.4505444444444. Wm2Back: 65.50858
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1400NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1400. Wm2Front: 558.2903111111111. Wm2Back: 65.49588
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1500NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1500. Wm2Front: 501.0515. Wm2Back: 64.40116
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-03-21_1600NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10.csv
# Index: 2021-03-21_1600. Wm2Front: 402.6767966666667. Wm2Back: 57.61826
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-03-21_1700NS_Tucson_Alb_0.22_CH_0.5_rtr_3.csv_Row10_Module10_Back
# ...
# Index: 2021-06-21_1900. Wm2Front: 69.7137822222222. Wm2Back: 24.418050000000004
# Creating ~15 skyfiles.
# Created 15 skyfiles in /skies/
#
# Making ~15 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 15 Radfiles created in /objects/
#
# Making 15 octfiles in root directory.
# Created 1axis_2021-06-21_0600.oct
# Created 1axis_2021-06-21_0700.oct
# Created 1axis_2021-06-21_0800.oct
# Created 1axis_2021-06-21_0900.oct
# Created 1axis_2021-06-21_1000.oct
# Created 1axis_2021-06-21_1100.oct
# Created 1axis_2021-06-21_1200.oct
# Created 1axis_2021-06-21_1300.oct
# Created 1axis_2021-06-21_1400.oct
# Created 1axis_2021-06-21_1500.oct
# Created 1axis_2021-06-21_1600.oct
# Created 1axis_2021-06-21_1700.oct
# Created 1axis_2021-06-21_1800.oct
# Created 1axis_2021-06-21_1900.oct
# Missing files, skipping...
# Linescan in process: 1axis_2021-06-21_0600EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_0600EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_0600EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_0600. Wm2Front: 4.914479. Wm2Back: 5.202796333333334
# Linescan in process: 1axis_2021-06-21_0700EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_0700EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_0700EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_0700. Wm2Front: 34.10332. Wm2Back: 50.0134988888889
# Linescan in process: 1axis_2021-06-21_0800EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_0800EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_0800EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_0800. Wm2Front: 67.6205. Wm2Back: 110.20453888888889
# Linescan in process: 1axis_2021-06-21_0900EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_0900EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_0900EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_0900. Wm2Front: 108.6963. Wm2Back: 183.97349222222223
# Linescan in process: 1axis_2021-06-21_1000EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1000EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1000EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1000. Wm2Front: 122.03699999999998. Wm2Back: 255.13939333333332
# Linescan in process: 1axis_2021-06-21_1100EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1100EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1100EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1100. Wm2Front: 136.019. Wm2Back: 339.9407111111111
# Linescan in process: 1axis_2021-06-21_1200EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1200EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1200EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1200. Wm2Front: 144.9348. Wm2Back: 433.4484555555556
# Linescan in process: 1axis_2021-06-21_1300EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1300EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1300EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1300. Wm2Front: 148.4928. Wm2Back: 528.9530555555555
# Linescan in process: 1axis_2021-06-21_1400EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1400EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1400EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1400. Wm2Front: 143.0838. Wm2Back: 689.9956222222222
# Linescan in process: 1axis_2021-06-21_1500EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1500EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1500EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1500. Wm2Front: 139.5991. Wm2Back: 817.4052555555555
# Linescan in process: 1axis_2021-06-21_1600EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1600EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1600EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1600. Wm2Front: 135.6404. Wm2Back: 817.3679111111111
# Linescan in process: 1axis_2021-06-21_1700EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1700EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1700EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1700. Wm2Front: 111.1103. Wm2Back: 378.2118222222222
# Linescan in process: 1axis_2021-06-21_1800EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1800EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1800EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1800. Wm2Front: 67.00488. Wm2Back: 196.13403333333335
# Linescan in process: 1axis_2021-06-21_1900EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1900EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1900EW_Tucson_Alb_0.8_CH_0.5_rtr_5.csv_Row10_Module10.csv
# Index: 2021-06-21_1900. Wm2Front: 68.04767. Wm2Back: 147.63534666666663
# Loading albedo, 1 value(s), 0.800 avg
# 1 nonzero albedo values.
# Warning: CSV file passed for input. Assuming it is TMY3style format
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
#
# Module Name: PVmodw
# Module PVmodw updated in module.json
# Pre-existing .rad file objects\PVmodw.rad will be overwritten
#
# Creating ~15 skyfiles.
# Created 15 skyfiles in /skies/
#
# Making ~15 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 15 Radfiles created in /objects/
#
# Making 15 octfiles in root directory.
# Created 1axis_2021-06-21_0600.oct
# Created 1axis_2021-06-21_0700.oct
# Created 1axis_2021-06-21_0800.oct
# Created 1axis_2021-06-21_0900.oct
# Created 1axis_2021-06-21_1000.oct
# Created 1axis_2021-06-21_1100.oct
# Created 1axis_2021-06-21_1200.oct
# Created 1axis_2021-06-21_1300.oct
# Created 1axis_2021-06-21_1400.oct
# Created 1axis_2021-06-21_1500.oct
# Created 1axis_2021-06-21_1600.oct
# Created 1axis_2021-06-21_1700.oct
# Created 1axis_2021-06-21_1800.oct
# Created 1axis_2021-06-21_1900.oct
# Missing files, skipping...
# Linescan in process: 1axis_2021-06-21_0600NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_0600NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_0600NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_0600. Wm2Front: 4.941385222222221. Wm2Back: 3.992842
# Linescan in process: 1axis_2021-06-21_0700NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_0700NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_0700NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_0700. Wm2Front: 53.80675444444444. Wm2Back: 29.69884
# Linescan in process: 1axis_2021-06-21_0800NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_0800NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_0800NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_0800. Wm2Front: 146.63961222222224. Wm2Back: 60.31432
# Linescan in process: 1axis_2021-06-21_0900NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_0900NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_0900NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_0900. Wm2Front: 270.9373111111111. Wm2Back: 92.21243
# Linescan in process: 1axis_2021-06-21_1000NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1000NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1000NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1000. Wm2Front: 375.94742222222226. Wm2Back: 110.4101
# Linescan in process: 1axis_2021-06-21_1100NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1100NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1100NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1100. Wm2Front: 506.0505. Wm2Back: 129.3951
# Linescan in process: 1axis_2021-06-21_1200NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1200NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1200NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1200. Wm2Front: 592.0901666666667. Wm2Back: 143.8689
# Linescan in process: 1axis_2021-06-21_1300NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1300NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1300NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1300. Wm2Front: 619.9651888888889. Wm2Back: 149.395
# Linescan in process: 1axis_2021-06-21_1400NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1400NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1400NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1400. Wm2Front: 584.9228666666666. Wm2Back: 141.2599
# Linescan in process: 1axis_2021-06-21_1500NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1500NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1500NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1500. Wm2Front: 502.8880222222223. Wm2Back: 130.7012
# Linescan in process: 1axis_2021-06-21_1600NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1600NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1600NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1600. Wm2Front: 386.91297777777777. Wm2Back: 113.10539999999999
# Linescan in process: 1axis_2021-06-21_1700NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1700NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1700NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1700. Wm2Front: 210.41084444444445. Wm2Back: 64.33567
# Linescan in process: 1axis_2021-06-21_1800NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1800NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1800NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1800. Wm2Front: 139.81882222222222. Wm2Back: 49.25969
# Linescan in process: 1axis_2021-06-21_1900NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Front
# Linescan in process: 1axis_2021-06-21_1900NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10_Back
# Saved: results\irr_1axis_2021-06-21_1900NS_Tucson_Alb_0.8_CH_0.75_rtr_2.csv_Row10_Module10.csv
# Index: 2021-06-21_1900. Wm2Front: 72.45941333333333. Wm2Back: 24.418050000000004
# Creating ~15 skyfiles.
# Created 15 skyfiles in /skies/
#
# Making ~15 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 15 Radfiles created in /objects/
#
# Making 15 octfiles in root directory.
# Created 1axis_2021-06-21_0600.oct
# Created 1axis_2021-06-21_0700.oct
# Created 1axis_2021-06-21_0800.oct
# Created 1axis_2021-06-21_0900.oct
# Created 1axis_2021-06-21_1000.oct
# Created 1axis_2021-06-21_1100.oct
# Created 1axis_2021-06-21_1200.oct
# Created 1axis_2021-06-21_1300.oct
# Created 1axis_2021-06-21_1400.oct
# Created 1axis_2021-06-21_1500.oct
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 34>()
#      66 demo.gendaylit1axis()
#      67 demo.makeScene1axis(module=mymodule,sceneDict=sceneDict) #makeScene creates a .rad file with 20 modules per row, 7 rows.
# ---> 68 demo.makeOct1axis()
#      69 demo.analysis1axis(customname=writefiletitle)
#
# File c:\users\sayala\documents\github\bifacial_radiance\bifacial_radiance\main.py:2015, in RadianceObj.makeOct1axis(self, trackerdict, singleindex, customname)
#    2013     filelist = self.materialfiles + [trackerdict[index]['skyfile'], trackerdict[index]['radfile']]
#    2014     octname = '1axis_%s%s'%(index, customname)
# -> 2015     trackerdict[index]['octfile'] = self.makeOct(filelist, octname)
#    2016 except KeyError as e:
#    2017     print('Trackerdict key error: {}'.format(e))
#
# File c:\users\sayala\documents\github\bifacial_radiance\bifacial_radiance\main.py:1961, in RadianceObj.makeOct(self, filelist, octname)
#    1959 filelist.insert(0,'oconv')
#    1960 with open('%s.oct' % (octname), "w") as f:
# -> 1961     _,err = _popen(filelist, None, f)
#    1962     #TODO:  exception handling for no sun up
#    1963     if err is not None:
#
# File c:\users\sayala\documents\github\bifacial_radiance\bifacial_radiance\main.py:97, in _popen(cmd, data_in, data_out)
#      94     shell=False
#      96 p = Popen(cmd, bufsize=-1, stdin=PIPE, stdout=data_out, stderr=PIPE, shell=shell) #shell=True required for Linux? quick fix, but may be security concern
# ---> 97 data, err = p.communicate(data_in)
#      99 if err:
#     100     if data:
#
# File ~\Anaconda3\lib\subprocess.py:1028, in Popen.communicate(self, input, timeout)
#    1025     endtime = None
#    1027 try:
# -> 1028     stdout, stderr = self._communicate(input, endtime, timeout)
#    1029 except KeyboardInterrupt:
#    1030     # https://bugs.python.org/issue25942
#    1031     # See the detailed comment in .wait().
#    1032     if timeout is not None:
#
# File ~\Anaconda3\lib\subprocess.py:1403, in Popen._communicate(self, input, endtime, orig_timeout)
#    1401         raise TimeoutExpired(self.args, orig_timeout)
#    1402 if self.stderr is not None:
# -> 1403     self.stderr_thread.join(self._remaining_time(endtime))
#    1404     if self.stderr_thread.is_alive():
#    1405         raise TimeoutExpired(self.args, orig_timeout)
#
# File ~\Anaconda3\lib\threading.py:1011, in Thread.join(self, timeout)
#    1008     raise RuntimeError("cannot join current thread")
#    1010 if timeout is None:
# -> 1011     self._wait_for_tstate_lock()
#    1012 else:
#    1013     # the behavior of a negative timeout isn't documented, but
#    1014     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1015     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\Anaconda3\lib\threading.py:1027, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1025 if lock is None:  # already determined that the C code is done
#    1026     assert self._is_stopped
# -> 1027 elif lock.acquire(block, timeout):
#    1028     lock.release()
#    1029     self._stop()
#
# KeyboardInterrupt:
