# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
import bifacial_radiance
import bifacialvf
print(bifacialvf.__version__)
print(bifacial_radiance.__version__)
# Out:
# 0.1.7-dev1+73.gf25ac0f.dirty
# 0.4.1+121.g952f921.dirty

# %%
testfolder = r'TEMP\SP2_02_21'
if not os.path.exists(testfolder):
    os.makedirs(testfolder)

# %%
# LOOP
pitchs = [8] #, 3, 5] 
CHs = [0.6] #, 0.5, 0.75, 1.0]
albedo = 0.72 #, 0.8]
locs = [722740] #, 727930 ]
locsnames = ['Tucson'] #, 'Seattle']

# %%
weatherfile = r'C:\Users\sayala\Documents\GitHub\Studies\SouthPole\Journals\SouthPole_2021_WeatherFile.csv'

# %%
demo = bifacial_radiance.RadianceObj('Sim', path=testfolder)
# Out:
# path = TEMP\SP2_02_21
# Making path: images
# Making path: objects
# Making path: results
# Making path: skies
# Making path: EPWs
# Making path: materials

# %%
#metdata = demo.readWeatherFile(weatherfile, starttime=idx, endtime=idx, source='SAM')

# %%
cumulativesky = False
startdate = ['12_21_12', '02_21_12']# , '06_21', '12_21']
startdate = ['12_21_11', '12_21_14', '12_21_17', '12_21_20', '12_21_18','12_21_23', '12_21_05', '12_21_02']# , '06_21', '12_21']
startdate = ['02_21_11', '02_21_14', '02_21_17', '02_21_20', '02_21_18','12_21_23', '02_21_05', '02_21_02']# , '06_21', '12_21']
sazmNS = 180
sazmEW = 90
limit_angle = 120
rowsWanted = [1,2,3,4,5]
modsWanted = [1,2,5,8,9]

for dd in range (0, len(startdate)):
        for zz in range(0, len(CHs)):
            for ww in range(0, len(pitchs)):

                    clearance_height = CHs[zz]
                    pitch = pitchs[ww]
                    gcr = 2/pitch
                    sdt = startdate[dd]
                    metdata = demo.readWeatherFile(weatherfile, starttime=sdt, endtime=sdt, source='SAM')  
                    
                    demo.setGround(albedo) 
                    mymodule = bifacial_radiance.ModuleObj(name='PVmod', x=1, y=2)
                    sceneDict = {'pitch':pitch,'clearance_height':clearance_height, 'nMods': 10, 'nRows': 5, 'azimuth': sazmNS}  
                    demo.set1axis(limit_angle = limit_angle, backtrack = False, gcr=gcr, cumulativesky = cumulativesky,
                                 fixed_tilt_angle=90, azimuth=sazmNS)
                    demo.gendaylit1axis()
                    demo.makeScene1axis(module=mymodule,sceneDict=sceneDict) #makeScene creates a .rad file with 20 modules per row, 7 rows.
                    demo.makeOct1axis()
                    for rr in range (0, len(rowsWanted)):
                        for mm in range(0, len(modsWanted)):
                            writefiletitle = '_NS_'+str(mm).zfill(2)+'-'+str(rr).zfill(2)+'_CH_'+str(clearance_height)+'_rtr_'+str(pitch)+'.csv'
                            demo.analysis1axis(customname=writefiletitle, sensorsy = [9,9], sensorsx = [6,6], 
                                               modWanted = modsWanted[mm], rowWanted = rowsWanted[rr])

                    sceneDict = {'pitch':pitch,'clearance_height':clearance_height, 'nMods': 9, 'nRows': 5, 'azimuth': sazmEW}  
                    demo.set1axis(limit_angle = limit_angle, backtrack = False, gcr=gcr, cumulativesky = cumulativesky,
                                 fixed_tilt_angle=90, azimuth=sazmEW)
                    demo.gendaylit1axis()
                    demo.makeScene1axis(module=mymodule,sceneDict=sceneDict) #makeScene creates a .rad file with 20 modules per row, 7 rows.
                    demo.makeOct1axis()
                    for rr in range (0, len(rowsWanted)):
                        for mm in range(0, len(modsWanted)):
                            writefiletitle = '_EW_'+str(mm).zfill(2)+'-'+str(rr).zfill(2)+'_CH_'+str(clearance_height)+'_rtr_'+str(pitch)+'.csv'
                            demo.analysis1axis(customname=writefiletitle, sensorsy = [9,9], sensorsx = [6,6], 
                                               modWanted = modsWanted[mm], rowWanted = rowsWanted[rr])
# Out:
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# WARNING: TMY interval was unable to be defined, so setting it to 1h.
# Calculating Sun position for Metdata that is left-labeled  with a delta of +30 mins. i.e. 12 is 12:30 sunpos.
# Loading albedo, 1 value(s), 0.720 avg
# 1 nonzero albedo values.
#
# Module Name: PVmod
# Module PVmod updated in module.json
# Pre-existing .rad file objects\PVmod.rad will be overwritten
#
# Creating ~1 skyfiles.
# Created 1 skyfiles in /skies/
#
# Making ~1 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 1 Radfiles created in /objects/
#
# Making 1 octfiles in root directory.
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1200: RuntimeWarning: invalid value encountered in remainder
#   H0 = np.degrees(np.arccos(cos_arg)) % 180
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1211: RuntimeWarning: invalid value encountered in remainder
#   m[1] = m[1] % 1
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1212: RuntimeWarning: invalid value encountered in remainder
#   m[2] = m[2] % 1
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1229: RuntimeWarning: invalid value encountered in remainder
#   Hp = (vs + lon - alpha_prime) % 360
# Created 1axis_2021-02-21_1100.oct
# Linescan in process: 1axis_2021-02-21_1100_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 490.2843425925926. Wm2Back: 1080.2676296296297
# Linescan in process: 1axis_2021-02-21_1100_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 477.0187777777777. Wm2Back: 1074.5465555555554
# Linescan in process: 1axis_2021-02-21_1100_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 459.75499259259243. Wm2Back: 1070.8938518518519
# Linescan in process: 1axis_2021-02-21_1100_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 469.00933703703697. Wm2Back: 1070.9872037037037
# Linescan in process: 1axis_2021-02-21_1100_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 479.2254296296297. Wm2Back: 1074.5780370370371
# Linescan in process: 1axis_2021-02-21_1100_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 482.14677777777786. Wm2Back: 929.513637037037
# Linescan in process: 1axis_2021-02-21_1100_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 467.8738666666667. Wm2Back: 907.9013037037038
# Linescan in process: 1axis_2021-02-21_1100_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 450.5581703703705. Wm2Back: 883.3777925925925
# Linescan in process: 1axis_2021-02-21_1100_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 461.95644999999996. Wm2Back: 911.1898962962963
# Linescan in process: 1axis_2021-02-21_1100_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 472.54588333333345. Wm2Back: 943.7018722222224
# Linescan in process: 1axis_2021-02-21_1100_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 482.15436111111114. Wm2Back: 923.3709425925925
# Linescan in process: 1axis_2021-02-21_1100_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 468.2734037037036. Wm2Back: 903.6473018518518
# Linescan in process: 1axis_2021-02-21_1100_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 449.9680000000001. Wm2Back: 878.0098962962961
# Linescan in process: 1axis_2021-02-21_1100_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 461.1548592592593. Wm2Back: 910.7142148148146
# Linescan in process: 1axis_2021-02-21_1100_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 471.7403537037037. Wm2Back: 939.7757833333335
# Linescan in process: 1axis_2021-02-21_1100_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 483.3466907407407. Wm2Back: 925.9756074074073
# Linescan in process: 1axis_2021-02-21_1100_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 468.84274814814813. Wm2Back: 904.9721388888889
# Linescan in process: 1axis_2021-02-21_1100_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 450.5025425925926. Wm2Back: 877.0919074074072
# Linescan in process: 1axis_2021-02-21_1100_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 462.18395740740743. Wm2Back: 908.1942833333333
# Linescan in process: 1axis_2021-02-21_1100_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 473.4451148148149. Wm2Back: 938.9993037037037
# Linescan in process: 1axis_2021-02-21_1100_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 526.6247351851852. Wm2Back: 925.8769666666667
# Linescan in process: 1axis_2021-02-21_1100_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 518.6874574074075. Wm2Back: 903.8662851851851
# Linescan in process: 1axis_2021-02-21_1100_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 511.2737314814815. Wm2Back: 881.9483666666666
# Linescan in process: 1axis_2021-02-21_1100_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 517.2099518518519. Wm2Back: 911.3896777777778
# Linescan in process: 1axis_2021-02-21_1100_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 524.029975925926. Wm2Back: 941.3033611111111
# Creating ~1 skyfiles.
# Created 1 skyfiles in /skies/
#
# Making ~1 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 1 Radfiles created in /objects/
#
# Making 1 octfiles in root directory.
# Created 1axis_2021-02-21_1100.oct
# Linescan in process: 1axis_2021-02-21_1100_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 565.3612777777777. Wm2Back: 612.6489111111111
# Linescan in process: 1axis_2021-02-21_1100_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 562.0102018518518. Wm2Back: 605.8136685185185
# Linescan in process: 1axis_2021-02-21_1100_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 560.9847851851852. Wm2Back: 598.5936944444444
# Linescan in process: 1axis_2021-02-21_1100_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 568.3675185185186. Wm2Back: 612.9110148148147
# Linescan in process: 1axis_2021-02-21_1100_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 573.7184944444444. Wm2Back: 621.6981092592592
# Linescan in process: 1axis_2021-02-21_1100_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 524.7591166666667. Wm2Back: 613.5337888888889
# Linescan in process: 1axis_2021-02-21_1100_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 516.6491203703704. Wm2Back: 604.415075925926
# Linescan in process: 1axis_2021-02-21_1100_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 509.2004462962963. Wm2Back: 598.422911111111
# Linescan in process: 1axis_2021-02-21_1100_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 523.2792333333333. Wm2Back: 612.1167944444444
# Linescan in process: 1axis_2021-02-21_1100_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 534.096712962963. Wm2Back: 621.102251851852
# Linescan in process: 1axis_2021-02-21_1100_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 524.2331537037036. Wm2Back: 612.5232055555556
# Linescan in process: 1axis_2021-02-21_1100_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 516.6930629629629. Wm2Back: 605.3609407407408
# Linescan in process: 1axis_2021-02-21_1100_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 508.7063388888889. Wm2Back: 597.757624074074
# Linescan in process: 1axis_2021-02-21_1100_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 523.587637037037. Wm2Back: 613.3669111111111
# Linescan in process: 1axis_2021-02-21_1100_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 533.0651796296296. Wm2Back: 621.8179055555555
# Linescan in process: 1axis_2021-02-21_1100_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 523.9705611111111. Wm2Back: 614.2053962962964
# Linescan in process: 1axis_2021-02-21_1100_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 515.9783444444444. Wm2Back: 607.4303481481481
# Linescan in process: 1axis_2021-02-21_1100_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 508.52540370370366. Wm2Back: 598.5901703703704
# Linescan in process: 1axis_2021-02-21_1100_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 523.8075203703704. Wm2Back: 612.4583407407408
# Linescan in process: 1axis_2021-02-21_1100_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 533.8525796296296. Wm2Back: 621.6138000000001
# Linescan in process: 1axis_2021-02-21_1100_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Index: 2021-02-21_1100. Wm2Front: 525.2861092592592. Wm2Back: 659.2802462962964
# Linescan in process: 1axis_2021-02-21_1100_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Index: 2021-02-21_1100. Wm2Front: 517.4529907407408. Wm2Back: 655.1796888888889
# Linescan in process: 1axis_2021-02-21_1100_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Index: 2021-02-21_1100. Wm2Front: 508.9967555555556. Wm2Back: 652.0001666666668
# Linescan in process: 1axis_2021-02-21_1100_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Index: 2021-02-21_1100. Wm2Front: 523.9800481481481. Wm2Back: 657.6984092592592
# Linescan in process: 1axis_2021-02-21_1100_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Front
# Linescan in process: 1axis_2021-02-21_1100_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1100_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Index: 2021-02-21_1100. Wm2Front: 534.0218648148149. Wm2Back: 660.5216722222222
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# WARNING: TMY interval was unable to be defined, so setting it to 1h.
# Calculating Sun position for Metdata that is left-labeled  with a delta of +30 mins. i.e. 12 is 12:30 sunpos.
# Loading albedo, 1 value(s), 0.720 avg
# 1 nonzero albedo values.
#
# Module Name: PVmod
# Module PVmod updated in module.json
# Pre-existing .rad file objects\PVmod.rad will be overwritten
#
# Creating ~1 skyfiles.
# Created 1 skyfiles in /skies/
#
# Making ~1 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 1 Radfiles created in /objects/
#
# Making 1 octfiles in root directory.
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1200: RuntimeWarning: invalid value encountered in remainder
#   H0 = np.degrees(np.arccos(cos_arg)) % 180
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1211: RuntimeWarning: invalid value encountered in remainder
#   m[1] = m[1] % 1
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1212: RuntimeWarning: invalid value encountered in remainder
#   m[2] = m[2] % 1
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1229: RuntimeWarning: invalid value encountered in remainder
#   Hp = (vs + lon - alpha_prime) % 360
# Created 1axis_2021-02-21_1400.oct
# Linescan in process: 1axis_2021-02-21_1400_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 365.92258518518514. Wm2Back: 647.6241277777777
# Linescan in process: 1axis_2021-02-21_1400_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 358.2031629629629. Wm2Back: 644.6884259259258
# Linescan in process: 1axis_2021-02-21_1400_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 349.22624814814816. Wm2Back: 641.4526777777778
# Linescan in process: 1axis_2021-02-21_1400_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 357.81300000000005. Wm2Back: 644.0022703703704
# Linescan in process: 1axis_2021-02-21_1400_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 365.08133518518525. Wm2Back: 644.472438888889
# Linescan in process: 1axis_2021-02-21_1400_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 363.9295351851853. Wm2Back: 587.9538425925925
# Linescan in process: 1axis_2021-02-21_1400_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 356.43657592592587. Wm2Back: 582.7741074074075
# Linescan in process: 1axis_2021-02-21_1400_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 347.5819907407407. Wm2Back: 584.2554740740741
# Linescan in process: 1axis_2021-02-21_1400_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 356.0075648148149. Wm2Back: 600.3094259259259
# Linescan in process: 1axis_2021-02-21_1400_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 364.2632518518519. Wm2Back: 607.6606537037037
# Linescan in process: 1axis_2021-02-21_1400_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 363.8009740740741. Wm2Back: 586.1282277777777
# Linescan in process: 1axis_2021-02-21_1400_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 356.6298462962963. Wm2Back: 582.4877055555556
# Linescan in process: 1axis_2021-02-21_1400_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 347.90665185185185. Wm2Back: 583.4973351851853
# Linescan in process: 1axis_2021-02-21_1400_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 356.5039629629629. Wm2Back: 599.0493907407408
# Linescan in process: 1axis_2021-02-21_1400_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 363.93918148148146. Wm2Back: 605.5089148148148
# Linescan in process: 1axis_2021-02-21_1400_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 364.4050092592593. Wm2Back: 586.5358407407407
# Linescan in process: 1axis_2021-02-21_1400_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 357.34541111111105. Wm2Back: 581.5341407407408
# Linescan in process: 1axis_2021-02-21_1400_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 348.28516666666667. Wm2Back: 583.9817907407408
# Linescan in process: 1axis_2021-02-21_1400_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 357.7129148148149. Wm2Back: 599.4020314814816
# Linescan in process: 1axis_2021-02-21_1400_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 364.7278425925925. Wm2Back: 605.5008648148147
# Linescan in process: 1axis_2021-02-21_1400_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 395.05833518518523. Wm2Back: 586.5097462962964
# Linescan in process: 1axis_2021-02-21_1400_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 391.81311481481475. Wm2Back: 581.729475925926
# Linescan in process: 1axis_2021-02-21_1400_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 389.93830925925937. Wm2Back: 584.6440685185185
# Linescan in process: 1axis_2021-02-21_1400_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 396.45475. Wm2Back: 599.2836648148149
# Linescan in process: 1axis_2021-02-21_1400_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 400.89002962962957. Wm2Back: 606.3074666666666
# Creating ~1 skyfiles.
# Created 1 skyfiles in /skies/
#
# Making ~1 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 1 Radfiles created in /objects/
#
# Making 1 octfiles in root directory.
# Created 1axis_2021-02-21_1400.oct
# Linescan in process: 1axis_2021-02-21_1400_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 391.84651111111117. Wm2Back: 646.6513777777778
# Linescan in process: 1axis_2021-02-21_1400_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 388.3450018518518. Wm2Back: 641.3511074074075
# Linescan in process: 1axis_2021-02-21_1400_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 387.56305925925926. Wm2Back: 659.4349203703704
# Linescan in process: 1axis_2021-02-21_1400_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 397.6603314814815. Wm2Back: 691.6778555555554
# Linescan in process: 1axis_2021-02-21_1400_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 403.9312296296296. Wm2Back: 703.3590240740741
# Linescan in process: 1axis_2021-02-21_1400_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 361.5084555555556. Wm2Back: 646.2826648148148
# Linescan in process: 1axis_2021-02-21_1400_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 353.68004074074076. Wm2Back: 640.3166851851852
# Linescan in process: 1axis_2021-02-21_1400_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 347.39847407407404. Wm2Back: 658.852835185185
# Linescan in process: 1axis_2021-02-21_1400_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 361.362787037037. Wm2Back: 693.1060462962964
# Linescan in process: 1axis_2021-02-21_1400_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 371.5920166666667. Wm2Back: 702.8337777777779
# Linescan in process: 1axis_2021-02-21_1400_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 360.65730370370363. Wm2Back: 645.6359629629632
# Linescan in process: 1axis_2021-02-21_1400_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 353.29134629629624. Wm2Back: 639.6699518518518
# Linescan in process: 1axis_2021-02-21_1400_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 347.17645555555544. Wm2Back: 658.8402333333332
# Linescan in process: 1axis_2021-02-21_1400_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 361.0030944444444. Wm2Back: 691.8431259259261
# Linescan in process: 1axis_2021-02-21_1400_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 370.64160925925927. Wm2Back: 703.6568203703704
# Linescan in process: 1axis_2021-02-21_1400_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 361.00522777777775. Wm2Back: 647.8187685185185
# Linescan in process: 1axis_2021-02-21_1400_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 353.2307777777777. Wm2Back: 642.9355981481482
# Linescan in process: 1axis_2021-02-21_1400_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 346.5198499999999. Wm2Back: 660.951038888889
# Linescan in process: 1axis_2021-02-21_1400_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 361.1288574074074. Wm2Back: 692.644274074074
# Linescan in process: 1axis_2021-02-21_1400_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 371.2957870370371. Wm2Back: 704.9732185185184
# Linescan in process: 1axis_2021-02-21_1400_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Index: 2021-02-21_1400. Wm2Front: 365.84695000000005. Wm2Back: 742.858238888889
# Linescan in process: 1axis_2021-02-21_1400_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Index: 2021-02-21_1400. Wm2Front: 357.9273296296297. Wm2Back: 738.7195648148148
# Linescan in process: 1axis_2021-02-21_1400_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Index: 2021-02-21_1400. Wm2Front: 348.6835425925926. Wm2Back: 737.3520555555556
# Linescan in process: 1axis_2021-02-21_1400_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Index: 2021-02-21_1400. Wm2Front: 362.4931425925927. Wm2Back: 739.8993388888889
# Linescan in process: 1axis_2021-02-21_1400_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Front
# Linescan in process: 1axis_2021-02-21_1400_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1400_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Index: 2021-02-21_1400. Wm2Front: 372.07690370370375. Wm2Back: 742.6763611111111
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# WARNING: TMY interval was unable to be defined, so setting it to 1h.
# Calculating Sun position for Metdata that is left-labeled  with a delta of +30 mins. i.e. 12 is 12:30 sunpos.
# Loading albedo, 1 value(s), 0.720 avg
# 1 nonzero albedo values.
#
# Module Name: PVmod
# Module PVmod updated in module.json
# Pre-existing .rad file objects\PVmod.rad will be overwritten
#
# Creating ~1 skyfiles.
# Created 1 skyfiles in /skies/
#
# Making ~1 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 1 Radfiles created in /objects/
#
# Making 1 octfiles in root directory.
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1200: RuntimeWarning: invalid value encountered in remainder
#   H0 = np.degrees(np.arccos(cos_arg)) % 180
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1211: RuntimeWarning: invalid value encountered in remainder
#   m[1] = m[1] % 1
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1212: RuntimeWarning: invalid value encountered in remainder
#   m[2] = m[2] % 1
# C:\Users\sayala\Documents\GitHub\pvlib-python\pvlib\spa.py:1229: RuntimeWarning: invalid value encountered in remainder
#   Hp = (vs + lon - alpha_prime) % 360
# Created 1axis_2021-02-21_1700.oct
# Linescan in process: 1axis_2021-02-21_1700_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Index: 2021-02-21_1700. Wm2Front: 681.8953981481483. Wm2Back: 633.1936462962964
# Linescan in process: 1axis_2021-02-21_1700_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Index: 2021-02-21_1700. Wm2Front: 673.8189777777778. Wm2Back: 629.6517259259259
# Linescan in process: 1axis_2021-02-21_1700_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Index: 2021-02-21_1700. Wm2Front: 663.1300611111111. Wm2Back: 627.0166555555554
# Linescan in process: 1axis_2021-02-21_1700_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Index: 2021-02-21_1700. Wm2Front: 675.0090592592593. Wm2Back: 632.695061111111
# Linescan in process: 1axis_2021-02-21_1700_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Index: 2021-02-21_1700. Wm2Front: 683.5425462962962. Wm2Back: 637.4446166666668
# Linescan in process: 1axis_2021-02-21_1700_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Index: 2021-02-21_1700. Wm2Front: 681.9759907407408. Wm2Back: 587.031912962963
# Linescan in process: 1axis_2021-02-21_1700_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Index: 2021-02-21_1700. Wm2Front: 671.4525370370371. Wm2Back: 577.2266037037037
# Linescan in process: 1axis_2021-02-21_1700_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Index: 2021-02-21_1700. Wm2Front: 662.518051851852. Wm2Back: 565.2783518518519
# Linescan in process: 1axis_2021-02-21_1700_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Index: 2021-02-21_1700. Wm2Front: 672.9573574074074. Wm2Back: 575.9911777777778
# Linescan in process: 1axis_2021-02-21_1700_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Index: 2021-02-21_1700. Wm2Front: 682.3408722222223. Wm2Back: 585.7568796296297
# Linescan in process: 1axis_2021-02-21_1700_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Index: 2021-02-21_1700. Wm2Front: 681.680424074074. Wm2Back: 586.0831296296298
# Linescan in process: 1axis_2021-02-21_1700_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Index: 2021-02-21_1700. Wm2Front: 671.219887037037. Wm2Back: 575.639375925926
# Linescan in process: 1axis_2021-02-21_1700_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Index: 2021-02-21_1700. Wm2Front: 661.9385203703705. Wm2Back: 562.3955462962963
# Linescan in process: 1axis_2021-02-21_1700_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Index: 2021-02-21_1700. Wm2Front: 673.2262425925926. Wm2Back: 575.3431833333333
# Linescan in process: 1axis_2021-02-21_1700_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Index: 2021-02-21_1700. Wm2Front: 681.9795703703704. Wm2Back: 585.1492981481482
# Linescan in process: 1axis_2021-02-21_1700_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Index: 2021-02-21_1700. Wm2Front: 683.3726518518517. Wm2Back: 585.3812185185185
# Linescan in process: 1axis_2021-02-21_1700_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Index: 2021-02-21_1700. Wm2Front: 673.882562962963. Wm2Back: 576.0365740740741
# Linescan in process: 1axis_2021-02-21_1700_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Index: 2021-02-21_1700. Wm2Front: 663.9972962962964. Wm2Back: 564.0748703703704
# Linescan in process: 1axis_2021-02-21_1700_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Index: 2021-02-21_1700. Wm2Front: 673.7772018518518. Wm2Back: 575.4354055555556
# Linescan in process: 1axis_2021-02-21_1700_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Index: 2021-02-21_1700. Wm2Front: 682.6114685185187. Wm2Back: 585.0751277777777
# Linescan in process: 1axis_2021-02-21_1700_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Index: 2021-02-21_1700. Wm2Front: 736.2796277777778. Wm2Back: 587.3849500000001
# Linescan in process: 1axis_2021-02-21_1700_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Index: 2021-02-21_1700. Wm2Front: 731.8136425925926. Wm2Back: 577.1346722222222
# Linescan in process: 1axis_2021-02-21_1700_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Index: 2021-02-21_1700. Wm2Front: 727.1783629629629. Wm2Back: 565.9854037037037
# Linescan in process: 1axis_2021-02-21_1700_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Index: 2021-02-21_1700. Wm2Front: 731.2990685185184. Wm2Back: 576.688261111111
# Linescan in process: 1axis_2021-02-21_1700_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Front
# Linescan in process: 1axis_2021-02-21_1700_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Back
# Saved: results\irr_1axis_2021-02-21_1700_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Index: 2021-02-21_1700. Wm2Front: 734.4873018518517. Wm2Back: 585.5843685185185
# Creating ~1 skyfiles.
# Created 1 skyfiles in /skies/
#
# Making ~1 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 1 Radfiles created in /objects/
#
# Making 1 octfiles in root directory.
# Created 1axis_2021-02-21_1700.oct
# Linescan in process: 1axis_2021-02-21_1700_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Front
# Linescan in process: 1axis_2021-02-21_1700_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Back
# Saved: results\irr_1axis_2021-02-21_1700_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Index: 2021-02-21_1700. Wm2Front: 601.9524240740741. Wm2Back: 1091.7250925925925
# Linescan in process: 1axis_2021-02-21_1700_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Front
# Linescan in process: 1axis_2021-02-21_1700_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Back
# ...
# Saved: results\irr_1axis_2021-02-21_0200_NS_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 618.4217314814815. Wm2Back: 406.0713870370369
# Linescan in process: 1axis_2021-02-21_0200_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 619.3633851851853. Wm2Back: 407.9574870370371
# Linescan in process: 1axis_2021-02-21_0200_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 652.9405666666667. Wm2Back: 391.26148333333333
# Linescan in process: 1axis_2021-02-21_0200_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 644.1661944444444. Wm2Back: 381.1895296296297
# Linescan in process: 1axis_2021-02-21_0200_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 625.8188851851853. Wm2Back: 364.32840740740744
# Linescan in process: 1axis_2021-02-21_0200_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 616.5113629629631. Wm2Back: 366.54400555555554
# Linescan in process: 1axis_2021-02-21_0200_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 617.3708648148148. Wm2Back: 371.9679296296296
# Linescan in process: 1axis_2021-02-21_0200_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 655.7235296296296. Wm2Back: 390.2449407407407
# Linescan in process: 1axis_2021-02-21_0200_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 645.0064592592591. Wm2Back: 381.5529055555555
# Linescan in process: 1axis_2021-02-21_0200_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 623.87285. Wm2Back: 363.3524111111111
# Linescan in process: 1axis_2021-02-21_0200_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 617.0246333333333. Wm2Back: 366.020824074074
# Linescan in process: 1axis_2021-02-21_0200_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 618.0742981481482. Wm2Back: 371.0833944444444
# Linescan in process: 1axis_2021-02-21_0200_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 654.4848537037038. Wm2Back: 390.86625555555554
# Linescan in process: 1axis_2021-02-21_0200_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 644.996185185185. Wm2Back: 381.0023240740741
# Linescan in process: 1axis_2021-02-21_0200_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 626.4536222222223. Wm2Back: 363.55765185185186
# Linescan in process: 1axis_2021-02-21_0200_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 618.5469499999999. Wm2Back: 365.64212407407405
# Linescan in process: 1axis_2021-02-21_0200_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 619.2224037037037. Wm2Back: 371.1584351851852
# Linescan in process: 1axis_2021-02-21_0200_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 688.7369462962963. Wm2Back: 391.5266537037037
# Linescan in process: 1axis_2021-02-21_0200_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 685.8324944444445. Wm2Back: 381.61593333333326
# Linescan in process: 1axis_2021-02-21_0200_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 682.0069777777779. Wm2Back: 364.810774074074
# Linescan in process: 1axis_2021-02-21_0200_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 684.1502703703702. Wm2Back: 368.08957777777783
# Linescan in process: 1axis_2021-02-21_0200_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_NS_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 685.8078740740742. Wm2Back: 372.8800018518519
# Creating ~1 skyfiles.
# Created 1 skyfiles in /skies/
#
# Making ~1 .rad files for gendaylit 1-axis workflow (this takes a minute..)
# 1 Radfiles created in /objects/
#
# Making 1 octfiles in root directory.
# Created 1axis_2021-02-21_0200.oct
# Linescan in process: 1axis_2021-02-21_0200_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_00-00_CH_0.6_rtr_8.csv_Row1_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 792.6305851851852. Wm2Back: 389.2927407407408
# Linescan in process: 1axis_2021-02-21_0200_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_01-00_CH_0.6_rtr_8.csv_Row1_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 790.0974074074073. Wm2Back: 378.764711111111
# Linescan in process: 1axis_2021-02-21_0200_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_02-00_CH_0.6_rtr_8.csv_Row1_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 786.27465. Wm2Back: 364.644574074074
# Linescan in process: 1axis_2021-02-21_0200_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_03-00_CH_0.6_rtr_8.csv_Row1_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 789.3347148148148. Wm2Back: 372.5669629629629
# Linescan in process: 1axis_2021-02-21_0200_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_04-00_CH_0.6_rtr_8.csv_Row1_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 792.456. Wm2Back: 380.860337037037
# Linescan in process: 1axis_2021-02-21_0200_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_00-01_CH_0.6_rtr_8.csv_Row2_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 752.9067314814814. Wm2Back: 388.2544166666666
# Linescan in process: 1axis_2021-02-21_0200_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_01-01_CH_0.6_rtr_8.csv_Row2_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 741.6959703703702. Wm2Back: 377.347387037037
# Linescan in process: 1axis_2021-02-21_0200_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_02-01_CH_0.6_rtr_8.csv_Row2_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 706.0250685185187. Wm2Back: 361.4813500000001
# Linescan in process: 1axis_2021-02-21_0200_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_03-01_CH_0.6_rtr_8.csv_Row2_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 692.8359944444445. Wm2Back: 367.7345629629629
# Linescan in process: 1axis_2021-02-21_0200_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_04-01_CH_0.6_rtr_8.csv_Row2_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 696.0183296296295. Wm2Back: 375.32186851851844
# Linescan in process: 1axis_2021-02-21_0200_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_00-02_CH_0.6_rtr_8.csv_Row3_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 751.9914833333333. Wm2Back: 387.84594629629635
# Linescan in process: 1axis_2021-02-21_0200_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_01-02_CH_0.6_rtr_8.csv_Row3_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 739.9119462962962. Wm2Back: 377.26496481481485
# Linescan in process: 1axis_2021-02-21_0200_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_02-02_CH_0.6_rtr_8.csv_Row3_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 703.9423518518518. Wm2Back: 362.02319074074074
# Linescan in process: 1axis_2021-02-21_0200_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_03-02_CH_0.6_rtr_8.csv_Row3_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 689.7949555555555. Wm2Back: 367.2132333333332
# Linescan in process: 1axis_2021-02-21_0200_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_04-02_CH_0.6_rtr_8.csv_Row3_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 694.1992074074076. Wm2Back: 374.32289259259267
# Linescan in process: 1axis_2021-02-21_0200_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_00-03_CH_0.6_rtr_8.csv_Row4_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 752.1386962962963. Wm2Back: 388.4269074074074
# Linescan in process: 1axis_2021-02-21_0200_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_01-03_CH_0.6_rtr_8.csv_Row4_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 738.8278592592591. Wm2Back: 378.703898148148
# Linescan in process: 1axis_2021-02-21_0200_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_02-03_CH_0.6_rtr_8.csv_Row4_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 702.1576074074072. Wm2Back: 361.92552037037035
# Linescan in process: 1axis_2021-02-21_0200_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_03-03_CH_0.6_rtr_8.csv_Row4_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 689.1504907407408. Wm2Back: 367.861624074074
# Linescan in process: 1axis_2021-02-21_0200_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_04-03_CH_0.6_rtr_8.csv_Row4_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 694.3754944444446. Wm2Back: 375.5581740740741
# Linescan in process: 1axis_2021-02-21_0200_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_00-04_CH_0.6_rtr_8.csv_Row5_Module1.csv
# Index: 2021-02-21_0200. Wm2Front: 751.9226203703702. Wm2Back: 422.3357685185186
# Linescan in process: 1axis_2021-02-21_0200_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_01-04_CH_0.6_rtr_8.csv_Row5_Module2.csv
# Index: 2021-02-21_0200. Wm2Front: 740.1936055555557. Wm2Back: 415.6795907407407
# Linescan in process: 1axis_2021-02-21_0200_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_02-04_CH_0.6_rtr_8.csv_Row5_Module5.csv
# Index: 2021-02-21_0200. Wm2Front: 705.012485185185. Wm2Back: 404.7474444444445
# Linescan in process: 1axis_2021-02-21_0200_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_03-04_CH_0.6_rtr_8.csv_Row5_Module8.csv
# Index: 2021-02-21_0200. Wm2Front: 690.1724203703706. Wm2Back: 403.8654518518519
# Linescan in process: 1axis_2021-02-21_0200_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Front
# Linescan in process: 1axis_2021-02-21_0200_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9_Back
# Saved: results\irr_1axis_2021-02-21_0200_EW_04-04_CH_0.6_rtr_8.csv_Row5_Module9.csv
# Index: 2021-02-21_0200. Wm2Front: 694.2546944444445. Wm2Back: 407.4808648148148
